# %%
import pandas as pd
import numpy as np
#import config as cfg
#import seaborn as sns

from sklearn.model_selection import train_test_split
import sklearn
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import RepeatedKFold, cross_val_score, KFold
from xgboost import XGBRegressor
from xgboost import plot_importance

# %% [markdown]
# <h2>1. Product Clicks </h2>

# %%
df_clicks =  pd.read_csv("Tables/prod_product_viewed.csv")

# %%
df_clicks = df_clicks[['id', 'brand', 'category', 'event', 'event_text', 'name', 'original_timestamp', 'timestamp',\
                       'price', 'product_id', 'price']]
df_clicks
# Out:
#                                                id             brand  \
# 0       ajs-next-a0fa08e1d278e7cf29e4180f5942fdf7           PROARTE
# 1       ajs-next-b79169f9cf90ebc151114ce3bd88be27        Wet n Wild
# 2       ajs-next-86a9f92af2427dc3c59169b745f47aed            Ustraa
# 3       ajs-next-838df329be126b305b37301cfbf7fcdd     The Face Shop
# 4       ajs-next-5380d8638d3f205d3fde9a67931a0931          Colorbar
# ...                                           ...               ...
# 107451  ajs-next-2eb55cb4f1abf0cae66057482d011459               AND
# 107452       936F9F8D-F71C-4069-8867-956D328AF4E1     Dolce&Gabbana
# 107453       BC1CE98C-02FF-4D59-9374-72F7A2A1EF2A  Carolina Herrera
# 107454       364BC995-6653-48DF-9BE1-E6768C4CD4EA      Paco Rabanne
# 107455       9c35e706-7ea1-4d1a-a9a4-528a21eb1ef4  Carolina Herrera
#
#                            category           event      event_text  \
# 0                        Brush Sets  product_viewed  Product Viewed
# 1             Sponges & Applicators  product_viewed  Product Viewed
# 2           Colognes & After Shaves  product_viewed  Product Viewed
# 3                       Sheet Masks  product_viewed  Product Viewed
# 4                  Eyebrow Enhancer  product_viewed  Product Viewed
# ...                             ...             ...             ...
# 107451  Womens Perfumes (EDT & EDP)  product_viewed  Product Viewed
# 107452  Womens Perfumes (EDT & EDP)  product_viewed  Product Viewed
# 107453  Womens Perfumes (EDT & EDP)  product_viewed  Product Viewed
# 107454  Womens Perfumes (EDT & EDP)  product_viewed  Product Viewed
# 107455  Womens Perfumes (EDT & EDP)  product_viewed  Product Viewed
#
#                                                      name  \
# 0                             PROARTE Pro Brush - (28Pcs)
# 1                     Wet N Wild Makeup Sponge Applicator
# 2             Ustraa After Dark Cologne Perfume - (100ml)
# 3       The Face Shop Real Nature Green Tea Face Sheet...
# 4       Colorbar Stunning Brow Mini Eyebrow Pencil - 0...
# ...                                                   ...
# 107451     And Love Muse EDP & Pretty Vogue Mist - (2Pcs)
# 107452      Dolce & Gabbana Pour Femme Intense EDP (50ml)
# 107453  Carolina Herrera Very Good Girl Eau De Parfum ...
# 107454  Paco Rabanne Pure XS for Her Eau De Parfum (50ml)
# 107455  Carolina Herrera 212 VIP Rose Eau De Parfum (5...
#
#                  original_timestamp                    timestamp    price  \
# 0       2022-12-28 12:56:45.816 UTC  2022-12-28 12:56:47.366 UTC  17000.0
# 1       2022-12-28 12:40:56.101 UTC  2022-12-28 12:40:56.843 UTC    509.0
# 2       2023-02-19 08:02:30.538 UTC  2023-02-19 08:02:31.199 UTC    611.0
# 3       2023-02-19 12:22:25.262 UTC  2023-02-19 12:22:25.271 UTC    100.0
# 4       2023-03-12 05:45:04.578 UTC  2023-03-12 05:45:04.433 UTC    239.0
# ...                             ...                          ...      ...
# 107451  2023-02-10 01:08:54.045 UTC  2023-02-10 01:08:54.041 UTC   1804.0
# 107452    2023-01-24 09:27:25.3 UTC  2023-01-24 09:27:25.884 UTC   7850.0
# 107453  2023-03-22 16:14:44.032 UTC  2023-03-22 16:14:44.271 UTC   8000.0
# 107454  2023-01-18 04:39:41.583 UTC  2023-01-18 04:39:41.833 UTC   5270.0
# 107455  2023-02-08 11:44:32.828 UTC  2023-02-08 11:44:33.402 UTC      0.0
#
#         product_id    price
# 0        7524675.0  17000.0
# 1        7530242.0    509.0
# 2        7504965.0    611.0
# 3        7538505.0    100.0
# 4        7502178.0    239.0
# ...            ...      ...
# 107451   7539766.0   1804.0
# 107452   7545438.0   7850.0
# 107453   7506000.0   8000.0
# 107454   7506583.0   5270.0
# 107455   7506329.0      0.0
#
# [107456 rows x 11 columns]

# %%
df_clicks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107456 entries, 0 to 107455
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  107456 non-null  object
#  1   brand               105503 non-null  object
#  2   category            105503 non-null  object
#  3   event               107456 non-null  object
#  4   event_text          107456 non-null  object
#  5   name                105476 non-null  object
#  6   original_timestamp  107456 non-null  object
#  7   timestamp           107456 non-null  object
#  8   price               105739 non-null  float64
#  9   product_id          105484 non-null  float64
#  10  price               105739 non-null  float64
# dtypes: float64(3), object(8)
# memory usage: 9.0+ MB

# %% [markdown]
# <h2>Brand-wise Clicks</h2>

# %%
df_clicks_brand = df_clicks.copy()
df_clicks_brand['brand'].value_counts()
# Out:
# Colorbar               7429
# M.A.C                  7286
# Lakme                  6414
# Estee Lauder           6162
# Maybelline New York    5965
#                        ...
# Osia Osia                 1
# Biorigin                  1
# Taali Foods               1
# Pepsodent                 1
# Elizabeth Taylor          1
# Name: brand, Length: 653, dtype: int64

# %%
df_clicks_brand['clicks'] = np.zeros(len(df_clicks_brand))
df_clicks_brand = df_clicks_brand.groupby('brand', as_index=False).agg({'clicks': 'count'})
df_clicks_brand.sort_values('clicks', ascending=False)
# Out:
#                    brand  clicks
# 138             Colorbar    7429
# 357                M.A.C    7286
# 334                Lakme    6414
# 191         Estee Lauder    6162
# 380  Maybelline New York    5965
# ..                   ...     ...
# 418         Naughty Girl       1
# 488             Purearth       1
# 54      Azafran Organics       1
# 134              Colgate       1
# 598       Tommy Hilfiger       1
#
# [653 rows x 2 columns]

# %% [markdown]
# <h2>Category-wise clicks<h2>

# %%
brand_to_category_dict = dict(zip(df_clicks['brand'], df_clicks['category']))
brand_to_category_dict
# Out:
# {'PROARTE': 'Eye Brush',
#  'Wet n Wild': 'Liquid Lipstick',
#  'Ustraa': 'Mens Deodorants & Roll-Ons',
#  'The Face Shop': 'Body Wash & Shower Gel',
#  'Colorbar': 'Body Wash & Shower Gel',
#  'Jaquline USA': 'Liquid Lipstick',
#  'Dot & Key': 'Serums & Essences',
#  'ASA beauty': 'Highlighters',
#  'AXE': 'Mens Deodorants & Roll-Ons',
#  'SUGAR Cosmetics': 'Serums & Essences',
#  'mCaffeine': 'Body Wash & Shower Gel',
#  'Wild Stone': 'Mens Deodorants & Roll-Ons',
#  'Power Gummies': 'Multivitamins',
#  'PAC': 'Face Moisturizer',
#  'Simply Nam': 'Liquid Lipstick',
#  'Vitro Naturals': 'Body Wash & Shower Gel',
#  'Vaseline': 'Body Wash & Shower Gel',
#  'Miss Claire': 'Liquid Lipstick',
#  'Gillette': 'Razors & Cartridges',
#  'Ikonic Professional': 'Hair Curling Irons',
#  'Truefitt & Hill': 'Face Moisturiser',
#  'Unpa': 'Serums & Essences',
#  'Pink Woolf': 'Face Wash',
#  'Plum': 'Womens Perfumes (EDT & EDP)',
#  'CLINIQUE': 'Womens Perfumes (EDT & EDP)',
#  'The Moms Co.': 'Serums & Essences',
#  'The Man Company': 'Mens Deodorants & Roll-Ons',
#  'PURECURE+CO': 'Nutritional Supplements',
#  'Bloomsberry': 'Body Wash & Shower Gel',
#  'Vega': 'Body Groomers',
#  'Too Faced': 'Liquid Lipstick',
#  "Pond's": 'Serums & Essence',
#  'St.Botanica': 'Body Wash & Shower Gel',
#  'Swiss Beauty': 'Serums & Essences',
#  'Mamaearth': 'Mens Perfumes (EDT & EDP)',
#  'Lakme': 'Serums & Essences',
#  'Marks & Spencer': 'Womens Perfumes (EDT & EDP)',
#  'Nutriment': 'Face Moisturizer',
#  'Star Struck by Sunny Leone': 'Liquid Lipstick',
#  'Faces Canada': 'Serums & Essences',
#  'Babila': 'Manicure & Pedicure Kits',
#  'Urban Gabru': 'Face Moisturizer',
#  'Half N Half': 'Highlighters',
#  'Olay': 'Serums & Essences',
#  'Fragrance & Beyond': 'Mens Perfumes (EDT & EDP)',
#  'Bioderma': 'Face Moisturizer',
#  'Bobbi Brown': 'Face Moisturizer',
#  'WOW SKIN SCIENCE': 'Body Wash & Shower Gel',
#  'Matt Look': 'Liquid Lipstick',
#  "L'Oreal Paris": 'Serums & Essences',
#  'OFRA': 'Liquid Lipstick',
#  'Daily Life Forever52': 'Serums & Essences',
#  'Biotique': 'Body Wash & Shower Gel',
#  'Mirah Belle': 'Body Wash & Shower Gel',
#  'Organic Harvest': 'Serums & Essences',
#  'VGR': 'Trimmers',
#  'Merlion Naturals': 'All Other Supplements',
#  'L’Oreal Paris': 'Liquid Lipstick',
#  'Uncle Tony': 'Face Moisturiser',
#  "Layer'r": 'Face Moisturiser',
#  'Indica': 'Hair Colour',
#  'Lifebuoy': 'Soaps',
#  'MYGLAMM': 'Body Wash & Shower Gel',
#  'Dyson': 'Rollers & Curlers',
#  'Garnier': 'Serums & Essences',
#  'Qraa': 'Masks & Peels',
#  'KAMA Ayurveda': 'Body Wash & Shower Gel',
#  'The Natural Wash': 'Serums & Essences',
#  'GUBB': 'Hair Color',
#  "L'occitane": 'Womens Perfumes (EDT & EDP)',
#  'SP': 'Conditioner',
#  'Arata': 'Body Wash & Shower Gel',
#  'Sotrue': 'Face Sunscreen',
#  'Keya Seth Aromatherapy': 'Lotions & Cream',
#  "Re'equil": 'Serums & Essences',
#  'Tabac': 'Hair Serum',
#  'Dove': 'Body Wash & Shower Gel',
#  'VOTRE': 'Serums & Essence',
#  'Innisfree': 'Serums & Essences',
#  'Skin Elements': 'Face Moisturizer',
#  'Nivea': 'Mens Deodorants & Roll-Ons',
#  'Mancode': 'Serums & Essence',
#  'Glamveda': 'Face Moisturiser',
#  'ST.JOHN': 'Mens Deodorants & Roll-Ons',
#  'Beauty People': 'Liquid Lipstick',
#  'Kimirica': 'Body Wash & Shower Gel',
#  "Dr. Sheth's": 'Masks & Peels',
#  'Basicare': 'Masks & Peels',
#  'Nair': 'Lotions & Cream',
#  'Bella Vita Organic': 'Womens Perfumes (EDT & EDP)',
#  'MAKEUP REVOLUTION LONDON': 'Liquid Lipstick',
#  'Ajmal': 'Womens Perfumes (EDT & EDP)',
#  'Bold Care': 'Mens Deodorants & Roll-Ons',
#  'L.A. Girl': 'Loose Powder',
#  'Streax': 'Hair Serum',
#  'Gemblue Biocare': 'Lotions & Cream',
#  'Beardo': 'Mens Deodorants & Roll-Ons',
#  'Spantra': 'Face Moisturizer',
#  'Batiste': 'Dry Shampoo',
#  '18.21 Man Made': 'Body Wash & Shower Gel',
#  'Matra': 'Serums & Essences',
#  'M.A.C': 'Face Moisturizer',
#  'Flormar': 'Liquid Lipstick',
#  'Revlon': 'Mens Deodorants & Roll-Ons',
#  'Depot': 'Conditioner',
#  'Bare Anatomy': 'Hair Serum',
#  'RENEE': 'Liquid Lipstick',
#  'Quench Botanics': 'Serums & Essences',
#  'Soulflower': 'Serums & Essences',
#  'Hajamat': 'Razors & Cartridges',
#  'Makeup Revolution': 'Serums & Essences',
#  'Earth Rhythm': 'Serums & Essences',
#  'Smashbox': 'Liquid Lipstick',
#  'Insight Cosmetics': 'Liquid Lipstick',
#  'Fixderma Cosmetic Laboratories': 'Body Wash & Shower Gel',
#  'Maui Moisture': 'Conditioner',
#  'Estee Lauder': 'Womens Perfumes (EDT & EDP)',
#  'Sugarbear': 'Biotin - Hair',
#  'PeeBuddy': 'Intimate Hygiene',
#  'O3+': 'Lotions & Cream',
#  "Nature's Essence": 'Face Moisturizer',
#  'Blue Heaven': 'Liquid Lipstick',
#  'Kairali': 'Conditioner',
#  'Activ Beaute': 'Face Wash',
#  'Organic India': 'All Other Supplements',
#  'TAC - The Ayurveda Co.': 'Face Wash',
#  'Toni&Guy': 'Conditioner',
#  'Indulgeo Essentials': 'Hair Serum',
#  'Farmacy Beauty': 'Serums & Essences',
#  'ODEON': 'Scrubs & Exfoliators',
#  'Love Beauty & Planet': 'Body Wash & Shower Gel',
#  'Carolina Herrera': 'Womens Perfumes (EDT & EDP)',
#  'Minimalist': 'Serums & Essences',
#  'Footlogix': 'Foot Creams',
#  'ZM Zayn & Myza': 'Serums & Essences',
#  'Lattafa': 'Womens Perfumes (EDT & EDP)',
#  'Invisibobble': 'Hair Accessories',
#  'DROMEN & CO': 'Serums & Essence',
#  'VLCC': 'Face Moisturizer',
#  'Mother Sparsh': 'Lotions & Cream',
#  'The Beard Story': 'Face Sunscreen',
#  'Berina': 'Face Moisturiser',
#  'Milk Shake': 'Conditioner',
#  'Detoxie': 'Face Wash',
#  'Armaf': 'Mens Perfumes (EDT & EDP)',
#  'BH Cosmetics': 'False Eyelashes',
#  'Mothercare': 'Wipes & Buds',
#  'MARS': 'Loose Powder',
#  'LUXURIATE': 'Face Wash',
#  'Aqualogica': 'Serums & Essences',
#  'Aroma Galaxy': 'Candles',
#  'India Grooming Club': 'Aftershave Lotion',
#  'Anastasia Beverly Hills': 'Loose Powder',
#  'Sanfe': 'Serums & Essences',
#  'Mikami': 'Hair Combs',
#  'Amul': 'Butter',
#  'Bombay Shaving Company': 'Masks & Peels',
#  'Lotus': 'Serums & Essences',
#  'Superdrug': 'Body Wash & Shower Gel',
#  "Palmer's": 'Lotions & Cream',
#  'Yves Rocher': 'Womens Perfumes (EDT & EDP)',
#  'Inatur': 'Lotions & Cream',
#  'VI-JOHN': 'Shaving Foams',
#  'Ktein': 'Dry Shampoo',
#  'Bhu Botanicals': 'Serums & Essence',
#  'Nandika': 'Lotions & Cream',
#  'Deborah Milano': 'Liquid Lipstick',
#  'Amazon Series': 'Conditioner',
#  'Ikin': 'Face Bleach',
#  'Anatomicals': 'Skin Cleanser',
#  'FURR': 'Serums & Essences',
#  'Wahl': 'Trimmers',
#  'Volamena': 'Body Wash & Shower Gel',
#  'LAIQA': 'Sanitary Napkins',
#  'ELINOR': 'Serums & Essence',
#  'BBlunt': 'Conditioner',
#  'BRYAN & CANDY': 'Body Wash & Shower Gel',
#  'Himalaya': 'Lotions & Cream',
#  'Nature Sure': 'Multivitamins',
#  'Anveya': 'Conditioner',
#  'Brillare': 'Face Moisturizer',
#  'Phy': 'Mens Perfumes (EDT & EDP)',
#  'VWash': 'Intimate Hygiene',
#  'Ayouthveda': 'Face Moisturiser',
#  'KAYA': 'Serums & Essences',
#  'Hawkins & Brimble': 'Shampoo',
#  'K18': 'Hair Masks',
#  'Lottie London': 'Highlighters',
#  'LAMBRE': 'Face Moisturizer',
#  'Oshea Herbals': 'Face Moisturiser',
#  'Fixderma': 'Face Moisturiser',
#  'Dermalogica': 'Face Moisturiser',
#  'Dafni': 'Hair Straighteners',
#  'Just Herbs': 'Conditioner',
#  "The Woman's Company": 'Body Groomers',
#  'Smiloshine': 'Floss & Tongue Cleaners',
#  'Up To Toe': 'Nail Care',
#  'Ciate London': 'Liquid Lipstick',
#  'Tresemme': 'Conditioner',
#  'Embryolisse': 'Face Moisturizer',
#  'Purearth': 'Face Oil',
#  'Toppik': 'Hair Spray',
#  'Aminu': 'Body Wash & Shower Gel',
#  'Maybelline New York': 'Liquid Lipstick',
#  '4711': 'Mens Perfumes (EDT & EDP)',
#  'Naturigin': 'Hair Colour',
#  'Hairtronic': 'Hair Brushes',
#  'Oxyglow': 'Face Moisturizer',
#  'Allure': 'Face Brush',
#  'Ital Veloce': 'Mens Body Mist & Sprays',
#  'Baby Dove': 'Body Wash & Shower Gel',
#  'Jovees': 'Serums & Essences',
#  'Caudalie': 'Serums & Essences',
#  'BIOSOFT': 'Lotions & Cream',
#  'Beardhood': 'Face Sunscreen',
#  'Chambor': 'Liquid Lipstick',
#  'Physicians Formula': 'Liquid Lipstick',
#  'True Frog': 'Skin Cleanser',
#  'House of Aroma': 'Candles',
#  'Kevin Murphy': 'Conditioner',
#  'Marc Anthony': 'Conditioner',
#  'Super Smelly': 'Masks & Peels',
#  'FOGG': 'Womens Perfumes (EDT & EDP)',
#  'SKIN COTTAGE': 'Body Wash & Shower Gel',
#  'Dashing Diva': 'Nail Art Kits',
#  'Majestique': 'Sponges & Applicators',
#  'Rome': 'Serums & Essences',
#  'De Fabulous': 'Conditioner',
#  'Lenphor': 'Liquid Lipstick',
#  'Nails On Board': 'Nail Art Kits',
#  'Pee Safe': 'Lotions & Cream',
#  'Jive': 'Womens Body Mist & Sprays',
#  'Urban Veda': 'Body Wash & Shower Gel',
#  'Bvlgari': 'Womens Perfumes (EDT & EDP)',
#  'Aaranyaa': 'Face Moisturizer',
#  'Wella Professionals': 'Conditioner',
#  'Bigen': 'Beard Colour',
#  'The Derma Co': 'Body Wash & Shower Gel',
#  'Love Earth': 'Serums & Essences',
#  'EMBARK': 'Womens Perfumes (EDT & EDP)',
#  'House of Beauty': 'Face Sunscreen',
#  'ETUDE HOUSE': 'Face Moisturizer',
#  'Glov': 'Massage Tool',
#  'Glutaglow': 'Hand & Foot Masks',
#  'Khadi Natural': 'Body Wash & Shower Gel',
#  'Gans': 'Mens Deodorants & Roll-Ons',
#  'Sirona': 'Body Wash & Shower Gel',
#  'Boujee Beauty': 'Face Brush',
#  'Passion Indulge': 'Face Moisturizer',
#  'Bella Voste': 'Liquid Lipstick',
#  'Lifelong': 'Trimmers',
#  'Tulips': 'Wipes & Buds',
#  'Aegte': 'Serums & Essences',
#  'The Organic Forest': 'Shampoo',
#  'Clovia Botaniqa': 'Body Wash & Shower Gel',
#  'Fashion Colour': 'Face Moisturiser',
#  'O.P.I': 'Nail Polish',
#  'Profusion Cosmetics': 'Eye Palettes',
#  'TVAM': 'Body Wash & Shower Gel',
#  'Secret Temptation': 'Womens Perfumes (EDT & EDP)',
#  '23 Yards': 'Pre & Post Shaves',
#  'BabyChakra': 'Lip Balm',
#  'Bomb Cosmetics': 'Body Wash & Shower Gel',
#  'Suganda': 'Serums & Essences',
#  'Old Spice': 'Shaving Creams',
#  'Diego Dalla Palma Milano': 'Face Moisturiser',
#  'Elizabeth Arden': 'Womens Perfumes (EDT & EDP)',
#  'NOTE': 'Eye Shadow',
#  'LetsShave': 'Shavers',
#  'Astaberry': 'Face Moisturizer',
#  'Kleral': 'Hair Serum',
#  "Ruby's Organics": 'Foundation',
#  'Shiseido': 'Serums & Essences',
#  'Oriental Botanics': 'Gift Sets',
#  'Alainne': 'Face Moisturiser',
#  'Carlton London': 'Womens Perfumes (EDT & EDP)',
#  "Rahul Phate's Research Product": 'Face Moisturizer',
#  'Dermafique': 'Serums & Essences',
#  'Vigini': 'Body Wash & Shower Gel',
#  'Via Tokyo Organic': 'Body Wash & Shower Gel',
#  'Deconstruct': 'Serums & Essences',
#  'Abercrombie & Fitch': 'Womens Perfumes (EDT & EDP)',
#  'Prolixr': 'Skin Cleanser',
#  'Finishing Touch Flawless': 'Face Epilator',
#  'Rejuvenating UBTAN': 'Toners',
#  'Priveda': 'Sheet Masks',
#  'Oral-B': 'Manual Toothbrush',
#  'L.A. Colors': 'Liquid Lipstick',
#  'Schwarzkopf': 'Conditioner',
#  'Hunter 1114': 'Conditioner',
#  'St. Ives': 'Body Wash & Shower Gel',
#  'Plume': 'Face Primer',
#  'United Colors Of Benetton': 'Womens Perfumes (EDT & EDP)',
#  'COROnation Herbal': 'Gels & Waxes',
#  'Miss Rose': 'Highlighters',
#  'Azafran Actives': 'Womens Perfumes (EDT & EDP)',
#  'Sery': 'Liquid Lipstick',
#  'Fran Wilson Moodmatcher': 'Lipstick',
#  "Johnson's Baby": 'Lotions & Cream',
#  'REMOVE': 'Lotions & Cream',
#  'The Skin Story': 'Face Sunscreen',
#  'Kal Hans Naturals': 'Face Sunscreen',
#  'Revolution Pro': 'Liquid Lipstick',
#  'Graceful Natural': 'Hair Colour',
#  'BPL': 'Grooming Kits',
#  'Minus 417': 'Serums & Essences',
#  'Belora Paris': 'Face Moisturizer',
#  'SO': 'Womens Body Mist & Sprays',
#  'Vaadi Herbals': 'Body Wash & Shower Gel',
#  'Too Cool For School': 'Body Butters',
#  'Xx Revolution': 'Eye Palettes',
#  'Swati Cosmetic': 'False Eyelashes',
#  'ManSure': 'All Other Supplements',
#  'The Beauty Co.': 'Masks & Peels',
#  'La Cremerie': 'Serums & Essences',
#  'Men Deserve': 'Face Wash',
#  'Adigo': 'Mens Deodorants & Roll-Ons',
#  'ACO Perfumes': 'Womens Perfumes (EDT & EDP)',
#  'INSIGHT Cosmetics': 'Liquid Lipstick',
#  'Ozone': 'Face Moisturizer',
#  'Coloressence': 'Liquid Lipstick',
#  'Revolution Haircare': 'Shampoo',
#  'Moha': 'Hair Oil',
#  'Royal Mirage': 'Colognes & After Shaves',
#  'LANEIGE': 'Serums & Essences',
#  'Botanic Love': 'Masks & Peels',
#  'GlowGlutathione': 'Multivitamins',
#  'Glimmer': 'Hair Combs',
#  'Skyn Organic Co.': 'Serums & Essences',
#  'Rexona': 'Mens Deodorants & Roll-Ons',
#  'Bio Oil': 'Face Moisturiser',
#  'Colgate Palmolive': 'Toothpaste',
#  'Skin Fx': 'Hand & Foot Masks',
#  'Janeke': 'Hair Combs',
#  'The Tribe Concepts': 'Skin Cleanser',
#  'LuxaDerme': 'Hand & Foot Masks',
#  'Trichup': 'Hair Oil',
#  'Sivanna': 'Eye Palettes',
#  'Balmain Paris Hair Couture': 'Conditioner',
#  'PLANTAS': 'Serums & Essences',
#  'Dicora Urban Fit': 'Body Wash & Shower Gel',
#  'Biotop Professional': 'Conditioner',
#  'MyGlamm': 'Loose Powder',
#  'LAFZ': 'Mens Deodorants & Roll-Ons',
#  'Greeko Man': 'Beard Oil',
#  'Skivia': 'Body Wash & Shower Gel',
#  'The Vintage Cosmetic Company': 'Brush Sets',
#  'Roots & Herbs': 'Body Wash & Shower Gel',
#  'SANCTUS': 'Serums & Essences',
#  'Life & Pursuits': 'Hair Oil',
#  'Sweet Heart': 'Womens Perfumes (EDT & EDP)',
#  'Dear, Klairs': 'Serums & Essences',
#  'MAKE UP ACADEMY': 'Eye Palettes',
#  'Nova': 'Hair Spray',
#  'Mocemsa': 'Womens Perfumes (EDT & EDP)',
#  "R.K'S Aroma": 'Skin Cleanser',
#  'Bare Body Essentials': 'Serums & Essences',
#  'Versace': 'Womens Perfumes (EDT & EDP)',
#  'TYMO': 'Hair Stylers',
#  'Antonio Banderas': 'Womens Perfumes (EDT & EDP)',
#  'Milani': 'Foundation',
#  'Atulya': 'Face Wash',
#  'Fabessentials by Fabindia': 'Lotions & Cream',
#  'Dewska': 'Body Wash & Soaps',
#  'Chemist At Play': 'Mens Deodorants & Roll-Ons',
#  'ALYUVA': 'Lotions & Cream',
#  'Fizzy Fern': 'Body Wash & Shower Gel',
#  'COAL CLEAN BEAUTY': 'Baby Care Lotions & Creams',
#  'Klavuu': 'Face Wash',
#  'Donna Chang': 'Body Lotions & Moisturizers',
#  "It's a 10 Haircare": 'Conditioner',
#  'Protouch': 'Serums & Essences',
#  'Buti Pure': 'Hair Color',
#  'The Pink Foundry': 'Serums & Essences',
#  'AND': 'Womens Perfumes (EDT & EDP)',
#  'Rene Furterer': 'Hair Serum',
#  'Neemli Naturals': 'Serums & Essences',
#  'Bodyguard': 'Wipes & Buds',
#  'DeBelle': 'Nail Polish',
#  'Sulwhasoo': 'Serums & Essences',
#  'Atopalm': 'Massage Oil',
#  'Skittles': 'Cream Biscuits',
#  'Rustic Art': 'Face Moisturizer',
#  'Sebamed': 'Body Wash & Shower Gel',
#  'Herbal Me': 'Hair Color',
#  'Sadhev': 'Face Moisturizer',
#  'Swisse': 'All Other Beauty Supplements',
#  'STARS': 'Loose Powder',
#  'Ramsons': 'Womens Perfumes (EDT & EDP)',
#  'KRAFTPRO': 'Hair Brushes',
#  'ORGANIC WORKS': 'Night Cream',
#  'Fuschia': 'Face Moisturiser',
#  'Khadi Essentials': 'Face Moisturiser',
#  'Koric': 'Eye Cream & Serums',
#  'Smoothskin': 'Epilators',
#  'Pinky Goat': 'False Eyelashes',
#  'The Cosmetic Republic': 'Shampoo',
#  'Bioayurveda': 'Eye Creams & Serums',
#  'Beplain': 'Face Moisturizer',
#  'BrownSkin Beauty': 'Serums & Essences',
#  'Globus Remedies': 'Face Wash',
#  's.Oliver': 'Womens Perfumes (EDT & EDP)',
#  "Chaitanya's": 'Multivitamins',
#  'Pielor': 'Sheet Masks',
#  'Tattvalogy': 'Toners',
#  'Anchor': 'Toothpaste',
#  'WishCare': 'Face Moisturiser',
#  'QOD Professional': 'Conditioner',
#  'Machismo': 'Hair Serum',
#  'Newsha': 'Conditioner',
#  'Pulp': 'Skin Cleanser',
#  'Giovanni': 'Conditioner',
#  'Coco Soul': 'Scrubs & Exfoliators',
#  'Ariul': 'Serums & Essences',
#  'Divinectar': 'Serums & Essence',
#  'IKWI': 'Multivitamins',
#  'Guess': 'Womens Perfumes (EDT & EDP)',
#  'SunScoop': 'Face Sunscreen',
#  'Forest Ffresh': 'All Other Supplements',
#  'Aloe Veda': 'Skin Cleanser',
#  'NUSUK': 'Mens Perfumes (EDT & EDP)',
#  'Kora Organics': 'Face Moisturizer',
#  'Mirabelle Cosmetics Korea': 'Sheet Masks',
#  'FAE BEAUTY': 'Serums & Essences',
#  'EveCare': 'Intimate Hygiene',
#  'Renewcell': 'Serums & Essences',
#  'The Beauty Sailor': 'Face Moisturiser',
#  'KIRO': 'Serums & Essences',
#  'Neyah': 'Nail Polish',
#  'Skin Secrets': 'Masks & Peels',
#  'Pierre Cardin Paris': 'Liquid Lipstick',
#  'Whisper': 'Sanitary Napkins',
#  'Alyssa Ashley': 'Womens Perfumes (EDT & EDP)',
#  'DISGUISE': 'Nail Polish',
#  'Swiss Image': 'Eye Cream & Serums',
#  'BEVERLY HILLS POLO CLUB': 'Mens Deodorants & Roll-Ons',
#  'MADES': 'Lip Balm',
#  'Tvachamrit Handcrafted Skincare': 'Body Scrubs & Exfoliants',
#  'HNK Hair N Kraft': 'Hair Dryers & Stylers',
#  'Medimade': 'Lotions & Cream',
#  'Khadi Swati': 'Face Wash',
#  'Ulric De Varens': 'Womens Perfumes (EDT & EDP)',
#  'Ikoo': 'Hair Masks',
#  'Aveeno': 'Lotions & Cream',
#  'Pepsodent': 'Toothpaste',
#  'Aravi Organic': 'Serums & Essence',
#  'ARRAS': 'Mens Deodorants & Roll-Ons',
#  'Namyaa': 'Serums & Essences',
#  'Nutrinorm Wellness': 'Face Moisturiser',
#  'Taali Foods': 'Salted Biscuits',
#  'Arias By Lara Dutta': 'Perfume',
#  'Colgate': 'Toothpaste',
#  nan: nan,
#  'Paese Cosmetics': 'Liquid Lipstick',
#  'Ilana': 'Face Primer',
#  'Tsara': 'Blush',
#  'Charmacy Milano': 'Highlighters',
#  'Street Wear': 'Liquid Lipstick',
#  'Auric': 'Liquid Lipstick',
#  'Elle 18': 'Liquid Lipstick',
#  'W': 'Nail Polish',
#  'INGLOT': 'Highlighters',
#  'Essence': 'Liquid Lipstick',
#  'Lux': 'Body Wash & Shower Gel',
#  'Osia Osia': 'Soaps',
#  'Liril': 'Body Wash & Shower Gel',
#  'Some By Mi': 'Serums & Essences',
#  'Moti': 'Soaps',
#  'Pears': 'Body Wash & Shower Gel',
#  '50AP': 'Soaps',
#  'Hada Secrets Japan': 'Conditioner',
#  'Azafran Active Botanicals': 'Soaps',
#  'Hamam': 'Soaps',
#  "Precious & Nature's": 'Soaps',
#  'Ketonska': 'Shampoo',
#  'Belif': 'Serums & Essences',
#  'ONE THING': 'Face Moisturizer',
#  'COSRX': 'Face Moisturizer',
#  'Dabur': 'Hair Oil',
#  'SNP Prep': 'Face Moisturizer',
#  'TASYA': 'Masks & Peels',
#  'Simple': 'Face Moisturizer',
#  'By Terry': 'Serums & Essences',
#  'Auric Select': 'Nail Polish',
#  'Bonjour Paris': 'Nail Polish',
#  'Jimmy Choo': 'Womens Perfumes (EDT & EDP)',
#  'Jean Paul Gaultier': 'Womens Perfumes (EDT & EDP)',
#  'Betty Barclay': 'Perfume',
#  'Narciso Rodriguez': 'Womens Perfumes (EDT & EDP)',
#  'Hugo Boss': 'Womens Perfumes (EDT & EDP)',
#  'Jacques Bogart': 'Mens Deodorants & Roll-Ons',
#  'Boss': 'Womens Perfumes (EDT & EDP)',
#  'Aigner': 'Womens Perfumes (EDT & EDP)',
#  'Nina Ricci': 'Perfume',
#  'Paco Rabanne': 'Womens Perfumes (EDT & EDP)',
#  'Shakira': 'Womens Perfumes (EDT & EDP)',
#  'Salvatore Ferragamo': 'Womens Perfumes (EDT & EDP)',
#  'Playboy': 'Womens Perfumes (EDT & EDP)',
#  'Coach': 'Womens Perfumes (EDT & EDP)',
#  'Moschino': 'Womens Perfumes (EDT & EDP)',
#  'Affetto by Sunny Leone': 'Womens Perfumes (EDT & EDP)',
#  'DAVIDOFF': 'Womens Perfumes (EDT & EDP)',
#  'Michael Kors': 'Womens Perfumes (EDT & EDP)',
#  'Lomani': 'Mens Deodorants & Roll-Ons',
#  'Chopard': 'Womens Perfumes (EDT & EDP)',
#  'Maxxcode': 'Womens Perfumes (EDT & EDP)',
#  'ALBATROSS': 'Womens Perfumes (EDT & EDP)',
#  'A Fragrance Story': 'Mens Perfumes (EDT & EDP)',
#  'RiiFFS': 'Mens Deodorants & Roll-Ons',
#  'Rihanah': 'Womens Perfumes (EDT & EDP)',
#  'Replay': 'Womens Perfumes (EDT & EDP)',
#  'Trussardi': 'Womens Perfumes (EDT & EDP)',
#  'Dolce & Gabbana': 'Mens Perfumes (EDT & EDP)',
#  'All Good Scents': 'Mens Perfumes (EDT & EDP)',
#  'Mercedes-Benz': 'Womens Perfumes (EDT & EDP)',
#  'M.Micallef': 'Womens Perfumes (EDT & EDP)',
#  'Police': 'Womens Perfumes (EDT & EDP)',
#  'Instyle': 'Mens Perfumes (EDT & EDP)',
#  'ESCADA': 'Womens Perfumes (EDT & EDP)',
#  'Dolce&Gabbana': 'Womens Perfumes (EDT & EDP)',
#  'Boucheron': 'Womens Perfumes (EDT & EDP)',
#  'NEUD': 'Serums & Essence',
#  'Montblanc': 'Womens Perfumes (EDT & EDP)',
#  'Ermenegildo Zegna': 'Perfume',
#  "LA' French": 'Womens Perfumes (EDT & EDP)',
#  'Naughty Girl': 'Perfume',
#  'Missoni': 'Womens Perfumes (EDT & EDP)',
#  'DKNY': 'Womens Perfumes (EDT & EDP)',
#  'Lanvin': 'Womens Perfumes (EDT & EDP)',
#  'Paris Hilton': 'Perfume',
#  'Global Desi': 'Womens Perfumes (EDT & EDP)',
#  'AL-Fakhr': 'Womens Perfumes (EDT & EDP)',
#  'Kenzo': 'Womens Perfumes (EDT & EDP)',
#  'Elie Saab': 'Perfume',
#  'Cadiveu': 'Face Primer',
#  'OGX': 'Conditioner',
#  'Clinic Plus': 'Shampoo',
#  'Head & Shoulders': 'Shampoo',
#  'Sunsilk': 'Conditioner',
#  'Meera': 'Shampoo',
#  'Indulekha': 'Hair Oil',
#  'Pantene': 'Shampoo',
#  'Jamriya': 'Shampoo',
#  'Chik': 'Shampoo',
#  'MALIBU C': 'Shampoo',
#  'Nyle': 'Shampoo',
#  'Hair Logic': 'Shampoo',
#  'JOVEES HERBAL': 'Shampoo',
#  'Thriveco': 'Face Moisturizer',
#  'Color Fever': 'Eyeliner',
#  'NICKA K': 'Liquid Lipstick',
#  'Truly Essential': 'Hair Oil',
#  'Essential Souls': 'Serums & Essence',
#  'The Pure Story': 'Hair Oil',
#  'Qurez': 'Face Sunscreen',
#  'Pure Sense': 'Lip Balm',
#  'C.A.L Los Angeles': 'Eye Shadow',
#  'LoveChild Masaba': 'Liquid Lipstick',
#  'Incolor': 'Nail Polish',
#  'She': 'Nail Polish',
#  'YC': 'Serums & Essences',
#  'Coccoon': 'Face Wash',
#  'Neutrogena': 'Face Moisturiser',
#  'Clean & Clear': 'Face Wash',
#  'Palmolive': 'Body Wash & Shower Gel',
#  'Aureana': 'Face Moisturizer',
#  'Saba': 'Nail Polish',
#  'ECOVANI': 'Serums & Essence',
#  'Fair & Lovely': 'Face Wash',
#  'Sedell': 'Lip Liner',
#  'I AM EYECONIC': 'Highlighters',
#  'Hair Toxx': 'Hair Serum',
#  'Ovin': 'Hair Serum',
#  'Vitress': 'Hair Serum',
#  'Biorigin': 'Hair Serum',
#  'Arganicare': 'Conditioner',
#  'Gorgy': 'Lip Crayon',
#  'Herbal Essences': 'Conditioner',
#  'Color Fx': 'Nail Polish',
#  'Ellement Co.': 'Nail Polish',
#  'Live Your Now (LYN)': 'Liquid Lipstick',
#  'INFINIA': 'Nail Polish',
#  'JUICE': 'Nail Polish',
#  'HOUSE OF MAKEUP': 'Liquid Lipstick',
#  'Jeffree Star Cosmetics': 'Liquid Lipstick',
#  'Pigment Play': 'Highlighters',
#  'LISEN': 'Serums & Essences',
#  'Love Organically': 'Masks & Peels',
#  'IORA': 'Serums & Essence',
#  'FCL': 'Masks & Peels',
#  'Urban Yog': 'Masks & Peels',
#  'CosIQ': 'Serums & Essences',
#  'Miracle Herbs': 'Skin Cleanser',
#  'Fair And Handsome': 'Skin Cleanser',
#  'Rebloom': 'Face Sunscreen',
#  'SEEKCAUS': 'Face Sunscreen',
#  "Ora d'oro Beauty": 'Liquid Lipstick',
#  'neyah': 'Liquid Lipstick',
#  'UXR': 'Body Wash & Shower Gel',
#  'Creme 21': 'Lotions & Cream',
#  'CALMYK': 'Lotions & Cream',
#  'Azafran Organics': 'Face Moisturiser',
#  'Glow & Lovely': 'Face Moisturizer',
#  'Bio Essence': 'Face Moisturizer',
#  "It's Skin": 'Face Moisturizer',
#  'Oceglow': 'Face Moisturiser',
#  'Lever Ayush': 'Face Moisturiser',
#  'Elvey Essentials': 'Body Wash & Shower Gel',
#  'BE SOULFULL': 'Serums & Essence',
#  'IBAEUTY': 'Serums & Essences',
#  'CEROC': 'Serums & Essences',
#  'Skinella': 'Serums & Essences',
#  'Yardley London': 'Body Wash & Shower Gel',
#  'Brut': 'Mens Deodorants & Roll-Ons',
#  'Numis Med': 'Body Wash & Shower Gel',
#  'Santoor': 'Body Wash & Shower Gel',
#  'Freeskin': 'Body Wash & Shower Gel',
#  'Lacoste': 'Womens Perfumes (EDT & EDP)',
#  'One8': 'Mens Deodorants & Roll-Ons',
#  'Bentley': 'Mens Perfumes (EDT & EDP)',
#  'Jaguar': 'Womens Perfumes (EDT & EDP)',
#  'Nautica': 'Mens Perfumes (EDT & EDP)',
#  'Calvin Klein': 'Mens Perfumes (EDT & EDP)',
#  'UPSILON': 'Mens Perfumes (EDT & EDP)',
#  'Hollister': 'Mens Perfumes (EDT & EDP)',
#  'Kenneth Cole': 'Mens Perfumes (EDT & EDP)',
#  'John Varvatos': 'Mens Perfumes (EDT & EDP)',
#  'Dunhill': 'Mens Perfumes (EDT & EDP)',
#  'Porsche': 'Mens Perfumes (EDT & EDP)',
#  'Samourai': 'Mens Perfumes (EDT & EDP)',
#  'Colour Me': 'Mens Perfumes (EDT & EDP)',
#  'Maryaj': 'Womens Perfumes (EDT & EDP)',
#  'Issey Miyake': 'Womens Perfumes (EDT & EDP)',
#  'James Bond 007': 'Womens Perfumes (EDT & EDP)',
#  'Eternal Love': 'Mens Perfumes (EDT & EDP)',
#  'David Beckham': 'Mens Deodorants & Roll-Ons',
#  'Aramis': 'Mens Perfumes (EDT & EDP)',
#  'Evaflor': 'Mens Deodorants & Roll-Ons',
#  'MANASIK': 'Mens Perfumes (EDT & EDP)',
#  'Frsh by Salman Khan': 'Mens Deodorants & Roll-Ons',
#  'Archies Parfum': 'Womens Perfumes (EDT & EDP)',
#  'DSQUARED2': 'Mens Perfumes (EDT & EDP)',
#  'JD COLLECTION': 'Mens Perfumes (EDT & EDP)',
#  'Just Jack': 'Mens Perfumes (EDT & EDP)',
#  'MONOTHEME': 'Womens Perfumes (EDT & EDP)',
#  'Bespoke London': 'Mens Deodorants & Roll-Ons',
#  'FC Barcelona': 'Mens Deodorants & Roll-Ons',
#  'HE': 'Mens Deodorants & Roll-Ons',
#  'Hott': 'Mens Deodorants & Roll-Ons',
#  'Envy': 'Mens Deodorants & Roll-Ons',
#  'Real Madrid': 'Mens Deodorants & Roll-Ons',
#  'Lolita Lempicka': 'Womens Perfumes (EDT & EDP)',
#  'Tommy Hilfiger': 'Womens Perfumes (EDT & EDP)',
#  'Elizabeth Taylor': 'Womens Perfumes (EDT & EDP)'}

# %%
len(brand_to_category_dict.keys())
# Out:
# 654

# %%
df_clicks_category = df_clicks.copy()
df_clicks_category['clicks'] = np.zeros(len(df_clicks_category))
df_clicks_category = df_clicks_category.groupby('category', as_index=False).agg({'clicks': 'count'})
df_clicks_category.sort_values('clicks', ascending=False)
# Out:
#                       category  clicks
# 134                   Lipstick   13248
# 91                  Foundation   12619
# 135            Liquid Lipstick    6897
# 153  Mens Perfumes (EDT & EDP)    4529
# 162                Nail Polish    3616
# ..                         ...     ...
# 25      Beauty & Personal Care       1
# 196  Stretch Mark Creams & Oil       1
# 4        Anti-Cellulite Creams       1
# 167         Omega 3 & Fish Oil       1
# 174            Salted Biscuits       1
#
# [211 rows x 2 columns]

# %% [markdown]
# <h2> 2. Order Completed </h2>

# %%
df_order_completed = pd.read_csv("Tables/prod_order_completed.csv")
df_order_completed = df_order_completed[df_order_completed['products'].isnull() == False]
df_order_completed
# Out:
#                                              id            event  \
# 0     ajs-next-353b3bbae250ca5e75ae35dbc4e9bbad  order_completed
# 1     ajs-next-edc545249f1bd71743b85eaddd8fae4c  order_completed
# 2     ajs-next-1601c54194fd585e0cc7032c5f94f0bc  order_completed
# 3     ajs-next-cd28c1aa890b9e7cd325c6b56e101375  order_completed
# 4     ajs-next-dfda63d40e976232f0c494c550cfc30b  order_completed
# ...                                         ...              ...
# 3302       EF5E4D5F-5BAF-4D67-BA86-5E69F9FCFCAE  order_completed
# 3303       C100E5B9-5DC3-4679-A418-29B72A129055  order_completed
# 3304       18D0E75E-211E-484A-917A-B44BEE0B4149  order_completed
# 3305       87C72BEE-1C7A-40BB-A173-A1E1811BD08B  order_completed
# 3306       FC15A33F-F8A4-4813-ACDA-5FDE27A5940C  order_completed
#
#            event_text              original_timestamp  \
# 0     Order Completed  2023-02-26 18:00:09.277000 UTC
# 1     Order Completed  2022-08-24 10:19:02.284000 UTC
# 2     Order Completed  2022-12-28 05:02:13.159000 UTC
# 3     Order Completed  2023-01-31 17:02:06.200000 UTC
# 4     Order Completed  2023-03-08 15:08:17.092000 UTC
# ...               ...                             ...
# 3302  Order Completed  2023-01-09 12:04:27.215000 UTC
# 3303  Order Completed  2023-01-07 17:05:19.838000 UTC
# 3304  Order Completed  2023-01-09 12:03:57.569000 UTC
# 3305  Order Completed  2023-01-09 12:22:07.610000 UTC
# 3306  Order Completed  2023-01-09 12:04:57.027000 UTC
#
#                            timestamp  \
# 0     2023-02-26 18:00:09.718000 UTC
# 1     2022-08-24 10:19:03.117000 UTC
# 2     2022-12-28 05:02:13.681000 UTC
# 3     2023-01-31 17:02:06.554000 UTC
# 4     2023-03-08 15:08:18.351000 UTC
# ...                              ...
# 3302  2023-01-09 12:04:27.738000 UTC
# 3303  2023-01-07 17:05:19.968000 UTC
# 3304  2023-01-09 12:03:58.046000 UTC
# 3305  2023-01-09 12:22:45.692000 UTC
# 3306  2023-01-09 12:04:57.552000 UTC
#
#                                                products
# 0     [{"brand":"Estee Lauder","name":"Estee Lauder ...
# 1     [{"item_brand":"Elle 18","item_id":7503415,"it...
# 2     [{"brand":"M.A.C","name":"M.A.C Matte Lipstick...
# 3     [{"brand":"Streax","name":"Streax Insta Shampo...
# 4     [{"brand":"Keya Seth Aromatherapy","name":"Key...
# ...                                                 ...
# 3302  [{"brand":"Garnier","category":"Hair Color","c...
# 3303  [{"brand":"Garnier","category":"Hair Color","c...
# 3304  [{"brand":"Garnier","category":"Hair Color","c...
# 3305  [{"brand":"Garnier","category":"Hair Color","c...
# 3306  [{"brand":"Garnier","category":"Hair Color","c...
#
# [2691 rows x 6 columns]

# %%
df_order_completed.iloc[2, 5]
# Out:
# '[{"brand":"M.A.C","name":"M.A.C Matte Lipstick - Please Me (3g)","price":1750,"product_id":7526540,"quantity":1},{"brand":"Estee Lauder","name":"Estee Lauder Advanced Night Repair Synchronized Multi-Recovery Complex - (50ml)","price":8250,"product_id":7532193,"quantity":1}]'

# %%
eval(df_order_completed.iloc[110, 5])
# Out:
# [{'brand': 'M.A.C',
#   'category': 'Face Primer',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'M.A.C Prep + Prime Fix+ - Original (100ml)',
#   'price': 1950,
#   'product_id': '7519188',
#   'quantity': 1},
#  {'brand': 'Plum',
#   'category': 'Skin Cleanser',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'Plum E-Luminence Simply Supple Cleansing Balm - (90g)',
#   'price': 545,
#   'product_id': '7523924',
#   'quantity': 1},
#  {'brand': 'Plum',
#   'category': 'Hair Oil',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'Plum Olive & Macadamia Nutri-Shield Pre-Shampoo Hair Oil - (90ml)',
#   'price': 650,
#   'product_id': '7528428',
#   'quantity': 1},
#  {'brand': 'Paco Rabanne',
#   'category': 'Mens Perfumes (EDT & EDP)',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'Paco Rabanne Olympea Intense Eau De Parfum (80ml)',
#   'price': 7200,
#   'product_id': '7506350',
#   'quantity': 1},
#  {'brand': 'Minimalist',
#   'category': 'Face Sunscreen',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'Minimalist Multi-vitamin SPF 50 PA ++++ Sunscreen - (50g)',
#   'price': 379.05,
#   'product_id': '7531921',
#   'quantity': 1},
#  {'brand': 'COSRX',
#   'category': 'Face Moisturizer',
#   'coupon': 'TIRAAPPRIL30 coupon applied',
#   'currency': 'INR',
#   'name': 'COSRX Advanced Snail 96 Mucin Power Essence (100ml)',
#   'price': 1232.5,
#   'product_id': '7522436',
#   'quantity': 1}]

# %%
df_order_completed = pd.concat([pd.DataFrame(eval(x)) for x in df_order_completed['products']], \
                               keys=df_order_completed['original_timestamp']).reset_index(level=1, drop=True).reset_index()
df_order_completed
# Out:
#                   original_timestamp         brand  \
# 0     2023-02-26 18:00:09.277000 UTC  Estee Lauder
# 1     2022-08-24 10:19:02.284000 UTC           NaN
# 2     2022-12-28 05:02:13.159000 UTC         M.A.C
# 3     2022-12-28 05:02:13.159000 UTC  Estee Lauder
# 4     2023-01-31 17:02:06.200000 UTC        Streax
# ...                              ...           ...
# 5685  2023-01-09 12:04:27.215000 UTC       Garnier
# 5686  2023-01-07 17:05:19.838000 UTC       Garnier
# 5687  2023-01-09 12:03:57.569000 UTC       Garnier
# 5688  2023-01-09 12:22:07.610000 UTC       Garnier
# 5689  2023-01-09 12:04:57.027000 UTC       Garnier
#
#                                                    name   price product_id  \
# 0     Estee Lauder Advanced Night Repair Synchronize...   540.0    7532189
# 1                                                   NaN     NaN        NaN
# 2                 M.A.C Matte Lipstick - Please Me (3g)  1750.0    7526540
# 3     Estee Lauder Advanced Night Repair Synchronize...  8250.0    7532193
# 4     Streax Insta Shampoo Hair Colour - 3 Dark Brow...    25.0    7545612
# ...                                                 ...     ...        ...
# 5685  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5686  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5687  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5688  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5689  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
#
#       quantity item_brand    item_id  \
# 0          2.0        NaN        NaN
# 1          NaN    Elle 18  7503415.0
# 2          1.0        NaN        NaN
# 3          1.0        NaN        NaN
# 4          1.0        NaN        NaN
# ...        ...        ...        ...
# 5685       1.0        NaN        NaN
# 5686       1.0        NaN        NaN
# 5687       1.0        NaN        NaN
# 5688       1.0        NaN        NaN
# 5689       1.0        NaN        NaN
#
#                                               item_name    category coupon  \
# 0                                                   NaN         NaN    NaN
# 1     Elle18 Color Pop Matte Lip Color - W12 Mauve D...         NaN    NaN
# 2                                                   NaN         NaN    NaN
# 3                                                   NaN         NaN    NaN
# 4                                                   NaN         NaN    NaN
# ...                                                 ...         ...    ...
# 5685                                                NaN  Hair Color
# 5686                                                NaN  Hair Color
# 5687                                                NaN  Hair Color
# 5688                                                NaN  Hair Color
# 5689                                                NaN  Hair Color
#
#      currency  category_id image_url size  item_price  item_quantity
# 0         NaN          NaN       NaN  NaN         NaN            NaN
# 1         NaN          NaN       NaN  NaN         NaN            NaN
# 2         NaN          NaN       NaN  NaN         NaN            NaN
# 3         NaN          NaN       NaN  NaN         NaN            NaN
# 4         NaN          NaN       NaN  NaN         NaN            NaN
# ...       ...          ...       ...  ...         ...            ...
# 5685      INR          NaN       NaN  NaN         NaN            NaN
# 5686      INR          NaN       NaN  NaN         NaN            NaN
# 5687      INR          NaN       NaN  NaN         NaN            NaN
# 5688      INR          NaN       NaN  NaN         NaN            NaN
# 5689      INR          NaN       NaN  NaN         NaN            NaN
#
# [5690 rows x 17 columns]

# %%
df_order_completed = df_order_completed.fillna('0')
for i, row in df_order_completed.iterrows():
    if (row['brand'] == '0'):
        row['brand'] = row['item_brand']
    if (row['name'] == '0'):
        row['name'] = row['item_name']
    if (row['product_id'] == '0'):
        row['product_id'] = row['item_id']
    if (row['category'] == '0'):
        if (row['brand'] in brand_to_category_dict.keys()):
            row['category'] = brand_to_category_dict[row['brand']]
    if (row['price'] == '0'):
        row['price'] = row['item_price']
    if (row['quantity'] == '0'):
        row['quantity'] = row['item_quantity']

# %%
df_order_completed.drop(['item_brand', 'item_id', 'item_name', 'coupon', 'currency', 'category_id', 'image_url', 'size', 'item_price', 'item_quantity'], axis=1, inplace=True)

# %%
df_order_completed
# Out:
#                   original_timestamp         brand  \
# 0     2023-02-26 18:00:09.277000 UTC  Estee Lauder
# 1     2022-08-24 10:19:02.284000 UTC       Elle 18
# 2     2022-12-28 05:02:13.159000 UTC         M.A.C
# 3     2022-12-28 05:02:13.159000 UTC  Estee Lauder
# 4     2023-01-31 17:02:06.200000 UTC        Streax
# ...                              ...           ...
# 5685  2023-01-09 12:04:27.215000 UTC       Garnier
# 5686  2023-01-07 17:05:19.838000 UTC       Garnier
# 5687  2023-01-09 12:03:57.569000 UTC       Garnier
# 5688  2023-01-09 12:22:07.610000 UTC       Garnier
# 5689  2023-01-09 12:04:57.027000 UTC       Garnier
#
#                                                    name   price product_id  \
# 0     Estee Lauder Advanced Night Repair Synchronize...   540.0    7532189
# 1     Elle18 Color Pop Matte Lip Color - W12 Mauve D...       0  7503415.0
# 2                 M.A.C Matte Lipstick - Please Me (3g)  1750.0    7526540
# 3     Estee Lauder Advanced Night Repair Synchronize...  8250.0    7532193
# 4     Streax Insta Shampoo Hair Colour - 3 Dark Brow...    25.0    7545612
# ...                                                 ...     ...        ...
# 5685  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5686  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5687  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5688  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5689  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
#
#      quantity                     category
# 0         2.0  Womens Perfumes (EDT & EDP)
# 1           0              Liquid Lipstick
# 2         1.0             Face Moisturizer
# 3         1.0  Womens Perfumes (EDT & EDP)
# 4         1.0                   Hair Serum
# ...       ...                          ...
# 5685      1.0                   Hair Color
# 5686      1.0                   Hair Color
# 5687      1.0                   Hair Color
# 5688      1.0                   Hair Color
# 5689      1.0                   Hair Color
#
# [5690 rows x 7 columns]

# %%
df_order_completed['price'] = df_order_completed['price'].astype(float)
df_order_completed['quantity'] = df_order_completed['quantity'].astype(float)

df_order_completed['quantity'] = df_order_completed['quantity'].apply(lambda x: 1 if x == 0 else x)
df_order_completed['category'] = df_order_completed['category'].apply(lambda x: 'not set' if x == '0' else x)
df_order_completed
# Out:
#                   original_timestamp         brand  \
# 0     2023-02-26 18:00:09.277000 UTC  Estee Lauder
# 1     2022-08-24 10:19:02.284000 UTC       Elle 18
# 2     2022-12-28 05:02:13.159000 UTC         M.A.C
# 3     2022-12-28 05:02:13.159000 UTC  Estee Lauder
# 4     2023-01-31 17:02:06.200000 UTC        Streax
# ...                              ...           ...
# 5685  2023-01-09 12:04:27.215000 UTC       Garnier
# 5686  2023-01-07 17:05:19.838000 UTC       Garnier
# 5687  2023-01-09 12:03:57.569000 UTC       Garnier
# 5688  2023-01-09 12:22:07.610000 UTC       Garnier
# 5689  2023-01-09 12:04:57.027000 UTC       Garnier
#
#                                                    name   price product_id  \
# 0     Estee Lauder Advanced Night Repair Synchronize...   540.0    7532189
# 1     Elle18 Color Pop Matte Lip Color - W12 Mauve D...     0.0  7503415.0
# 2                 M.A.C Matte Lipstick - Please Me (3g)  1750.0    7526540
# 3     Estee Lauder Advanced Night Repair Synchronize...  8250.0    7532193
# 4     Streax Insta Shampoo Hair Colour - 3 Dark Brow...    25.0    7545612
# ...                                                 ...     ...        ...
# 5685  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5686  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5687  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5688  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
# 5689  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
#
#       quantity                     category
# 0          2.0  Womens Perfumes (EDT & EDP)
# 1          1.0              Liquid Lipstick
# 2          1.0             Face Moisturizer
# 3          1.0  Womens Perfumes (EDT & EDP)
# 4          1.0                   Hair Serum
# ...        ...                          ...
# 5685       1.0                   Hair Color
# 5686       1.0                   Hair Color
# 5687       1.0                   Hair Color
# 5688       1.0                   Hair Color
# 5689       1.0                   Hair Color
#
# [5690 rows x 7 columns]

# %%
df_order_completed.sort_values('quantity', ascending=False)
# Out:
#                   original_timestamp           brand  \
# 2634  2023-02-16 17:41:05.721000 UTC            Dove
# 2439  2023-01-03 06:02:50.101000 UTC        Biotique
# 2037  2023-01-04 12:48:45.364000 UTC  Vitro Naturals
# 3129  2023-01-19 14:59:40.696000 UTC     Blue Heaven
# 3238  2023-03-22 20:11:16.156000 UTC    Estee Lauder
# ...                              ...             ...
# 1979  2023-03-19 06:27:27.087000 UTC           Lakme
# 1978  2023-03-19 06:27:27.087000 UTC           Lakme
# 1977  2023-03-11 06:02:55.218000 UTC      Minimalist
# 1976  2023-03-11 06:02:55.218000 UTC        Himalaya
# 5689  2023-01-09 12:04:57.027000 UTC         Garnier
#
#                                                    name   price product_id  \
# 2634         Dove Cream Beauty Bathing Bar Soap - (50g)    27.0    7547386
# 2439  Biotique Basil & Parsley Revitalizing Bathing ...    60.0    7500872
# 2037  Vitro I Am Natural Premium Gulab Jal (Rose Wat...   179.0    7527858
# 3129      Blue Heaven Instant Nail Paint Remover (28ml)    40.5    7537691
# 3238  Estee Lauder Nutritious Super Pomegranate Radi...  3000.0    7524005
# ...                                                 ...     ...        ...
# 1979  Lakme Blush & Glow Lemon Freshness Gel Face Wa...   175.0    7551364
# 1978  Lakme Sun Expert SPF 30 Ultra Matte Lotion (10...   359.0    7546957
# 1977  Minimalist 2% Salicylic Acid + LHA Cleanser Re...   284.0    7524004
# 1976          Himalaya Purifying Neem Face Wash (100ml)   150.0    7521074
# 5689  Garnier Men Shampoo Based Hair Color - Shade 3...    29.0    7505256
#
#       quantity                category
# 2634     100.0                   Soaps
# 2439      44.0  Body Wash & Shower Gel
# 2037      17.0                    Mist
# 3129      17.0         Liquid Lipstick
# 3238      16.0           Skin Cleanser
# ...        ...                     ...
# 1979       1.0       Serums & Essences
# 1978       1.0       Serums & Essences
# 1977       1.0       Serums & Essences
# 1976       1.0         Lotions & Cream
# 5689       1.0              Hair Color
#
# [5690 rows x 7 columns]

# %% [markdown]
# <h2>Brand-wise</h2>

# %%
df_order_completed_brand = df_order_completed.copy()

# %%
df_order_completed_brand['no_of_unique_purchases'] = np.zeros(len(df_order_completed_brand))

df_grouped = df_order_completed_brand.groupby('brand', as_index=False).agg({'price':'sum', 'quantity':'sum', 'no_of_unique_purchases': 'count'})
df_grouped.rename(columns={'quantity':'no_of_purchases'}, inplace=True)
df_grouped.sort_values(by='no_of_unique_purchases', ascending=False, inplace=True)
df_grouped
# Out:
#                    brand      price  no_of_purchases  no_of_unique_purchases
# 163                Lakme  100311.54            382.0                     352
# 73              Colorbar   50252.30            279.0                     263
# 194  Maybelline New York   96092.45            236.0                     212
# 112              Garnier   11995.95            245.0                     207
# 246                 Plum   67432.35            189.0                     181
# ..                   ...        ...              ...                     ...
# 264               Rexona      38.00              1.0                       1
# 263       Revolution Pro     850.00              1.0                       1
# 162              Lacoste    4500.00              1.0                       1
# 261            Renewcell    1099.00              1.0                       1
# 193             Maxxcode     130.00              1.0                       1
#
# [350 rows x 4 columns]

# %%
df_grouped[df_grouped['brand'] == 'Dove']
# Out:
#    brand     price  no_of_purchases  no_of_unique_purchases
# 89  Dove  12698.44            201.0                      91

# %%
df_order_completed_brand = df_grouped.copy()

# %% [markdown]
# <h2>Category wise</h2>

# %%
df_order_completed_category = df_order_completed.copy()

# %%
df_order_completed_category['no_of_unique_purchases'] = np.zeros(len(df_order_completed_category))

df_grouped = df_order_completed_category.groupby('category', as_index=False).agg({'price':'sum', 'quantity':'sum', 'no_of_unique_purchases': 'count'})
df_grouped.rename(columns={'quantity':'no_of_purchases'}, inplace=True)
df_grouped.sort_values(by='no_of_unique_purchases', ascending=False, inplace=True)
df_grouped
# Out:
#                         category      price  no_of_purchases  \
# 124            Serums & Essences  464036.59           1140.0
# 24        Body Wash & Shower Gel  199738.92            802.0
# 97               Liquid Lipstick  195315.89            665.0
# 50              Face Moisturizer  310635.58            350.0
# 146  Womens Perfumes (EDT & EDP)  465384.11            364.0
# ..                           ...        ...              ...
# 113                Moustache Oil     249.00              1.0
# 114                Multivitamins     975.00              1.0
# 25             Body Wash & Soaps     265.00              1.0
# 120            Pre & Post Shaves     199.00              1.0
# 0                   Acne Removal      90.00              1.0
#
#      no_of_unique_purchases
# 124                    1059
# 24                      675
# 97                      589
# 50                      301
# 146                     300
# ..                      ...
# 113                       1
# 114                       1
# 25                        1
# 120                       1
# 0                         1
#
# [148 rows x 4 columns]

# %%
df_order_completed_category = df_grouped.copy()

# %% [markdown]
# <h2> 3. Adds to Wishlist </h2>

# %%
df_wishlist = pd.read_csv('Tables/prod_adds_to_wishlist.csv')
df_wishlist
# Out:
#                                               id                brand  \
# 0      ajs-next-015b7af6596d763141f3d46941181c03             Colorbar
# 1      ajs-next-3c228cfd2f01ea106b9334a279c7ad2b  India Grooming Club
# 2      ajs-next-6f9ab2addfcee447d343fca05b7e8f1f                 Vega
# 3      ajs-next-64cd4a9906319b038a2cb26402866a2a             Gillette
# 4      ajs-next-11fc7950c2e75f7c009cb6b57be395fb        L'Oreal Paris
# ...                                          ...                  ...
# 17386       8DD2C8BF-02B3-4FC7-A316-80FBD1C20096                 Dove
# 17387  ajs-next-cf9f70a38cfee45eb521566714b65b7d     Antonio Banderas
# 17388       EE89C4EF-8BF7-4984-9851-BD2A9B638C0F                Ajmal
# 17389  ajs-next-f227259e9202a58c277f5b1d293768e4                Nivea
# 17390  ajs-next-250ff0cf6903d3e3bb923e877a93ea0a      Ulric De Varens
#
#                            category                      event  \
# 0                       Hand Creams  product_added_to_wishlist
# 1                           Shavers  product_added_to_wishlist
# 2            Mani-Pedi Tools & Kits  product_added_to_wishlist
# 3               Razors & Cartridges  product_added_to_wishlist
# 4                       Hair Colour  product_added_to_wishlist
# ...                             ...                        ...
# 17386  Womens Deodorants & Roll-Ons  product_added_to_wishlist
# 17387  Womens Deodorants & Roll-Ons  product_added_to_wishlist
# 17388  Womens Deodorants & Roll-Ons  product_added_to_wishlist
# 17389  Womens Deodorants & Roll-Ons  product_added_to_wishlist
# 17390  Womens Deodorants & Roll-Ons  product_added_to_wishlist
#
#                       event_text  \
# 0      Product Added to Wishlist
# 1      Product Added to Wishlist
# 2      Product Added to Wishlist
# 3      Product Added to Wishlist
# 4      Product Added to Wishlist
# ...                          ...
# 17386  Product Added to Wishlist
# 17387  Product Added to Wishlist
# 17388  Product Added to Wishlist
# 17389  Product Added to Wishlist
# 17390  Product Added to Wishlist
#
#                                                     name  \
# 0      Colorbar Toast To Tahiti Fruit Drop Hand Cream...
# 1      India Grooming Club Black Shaving Razor Handle...
# 2                              set of Foot care, (PM-03)
# 3      Gillette Mach 3 Turbo Manual Shaving Razor Bla...
# 4      L'Oreal Paris Casting Creme Gloss Hair Color, ...
# ...                                                  ...
# 17386             Dove Original Deodorant Roll On (50ml)
# 17387  Antonio Banderas Blue Seduction for Women Deod...
# 17388  Ajmal Shadow Homme & Sacred Love Deodorant Spr...
# 17389  Nivea Women Fresh Natural Deodorant Roll On (5...
# 17390         Ulric De Varens Gold-Issme Deodrant 125 ml
#
#                 original_timestamp                    timestamp    price  \
# 0      2022-08-18 04:49:25.199 UTC  2022-08-18 04:49:25.534 UTC    275.0
# 1      2023-03-06 03:03:23.175 UTC  2023-03-06 03:03:23.144 UTC  16000.0
# 2        2023-03-06 07:43:28.6 UTC  2023-03-06 07:43:28.605 UTC      NaN
# 3      2023-02-25 11:07:47.504 UTC  2023-02-25 11:07:48.719 UTC      NaN
# 4      2023-02-26 17:54:36.813 UTC  2023-02-26 17:54:37.215 UTC      NaN
# ...                            ...                          ...      ...
# 17386  2023-02-02 05:36:59.426 UTC   2023-02-02 05:36:59.61 UTC    220.0
# 17387  2023-01-20 09:35:11.579 UTC  2023-01-20 09:35:12.191 UTC      NaN
# 17388  2023-02-16 16:29:36.695 UTC  2023-02-16 16:29:37.063 UTC    327.0
# 17389  2023-02-13 09:19:44.375 UTC  2023-02-13 09:19:44.676 UTC    172.0
# 17390  2022-08-08 07:17:13.606 UTC  2022-08-08 07:17:13.835 UTC    249.0
#
#        product_id  quantity
# 0       7504904.0       1.0
# 1       7521080.0       1.0
# 2       7513281.0       1.0
# 3       7547314.0       1.0
# 4       7500061.0       1.0
# ...           ...       ...
# 17386   7537511.0       1.0
# 17387   7506565.0       1.0
# 17388   7516334.0       1.0
# 17389   7516982.0       1.0
# 17390   7506867.0       1.0
#
# [17391 rows x 11 columns]

# %% [markdown]
# <h2>Brand wise</h2>

# %%
df_wishlist_brand = df_wishlist.copy()

# %%
df_wishlist_brand['no_of_adds_to_wishlist'] = np.zeros(len(df_wishlist_brand))
df_grouped = df_wishlist_brand.groupby('brand', as_index=False)[['brand', 'no_of_adds_to_wishlist', 'price']].\
    agg({'price': 'sum', 'no_of_adds_to_wishlist': 'count'}).sort_values('no_of_adds_to_wishlist', ascending= False)
df_grouped
# Out:
#                          brand      price  no_of_adds_to_wishlist
# 110                   Colorbar  1092163.0                    1686
# 271                      M.A.C  1330501.0                     893
# 288        Maybelline New York   318828.0                     585
# 149               Estee Lauder  1739285.0                     505
# 253                      Lakme   115849.0                     480
# ..                         ...        ...                     ...
# 346            Paese Cosmetics     1999.0                       1
# 343                    PROARTE        0.0                       1
# 154  Fabessentials by Fabindia      375.0                       1
# 156              Fair & Lovely       72.0                       1
# 129                    Detoxie        0.0                       1
#
# [493 rows x 3 columns]

# %%
df_wishlist_brand = df_grouped.copy()

# %% [markdown]
# <h2>Category Wise</h2>

# %%
df_wishlist_category = df_wishlist.copy()

# %%
df_wishlist_category['no_of_adds_to_wishlist'] = np.zeros(len(df_wishlist_category))
df_grouped = df_wishlist_category.groupby('category', as_index=False)[['category', 'no_of_adds_to_wishlist', 'price']].\
    agg({'price': 'sum', 'no_of_adds_to_wishlist': 'count'}).sort_values('no_of_adds_to_wishlist', ascending= False)
df_grouped
# Out:
#                       category      price  no_of_adds_to_wishlist
# 92                  Foundation  1646078.0                    1628
# 148                   Lipstick   768997.0                    1135
# 149            Liquid Lipstick   319832.0                     613
# 170  Mens Perfumes (EDT & EDP)  1630509.0                     599
# 51                   Concealer   436173.0                     543
# ..                         ...        ...                     ...
# 211  Shower Gels and Body Wash        0.0                       1
# 100                    Glimmer       39.0                       1
# 213           Skin Brightening        0.0                       1
# 101              Grooming Kits        0.0                       1
# 0                          AXE       78.0                       1
#
# [236 rows x 3 columns]

# %%
df_wishlist_category = df_grouped.copy()

# %% [markdown]
# <h2> 4. Adds to Cart </h2>

# %%
df_cart = pd.read_csv('tables/prod_adds_to_cart.csv')
df_cart
# Out:
#                                               id                brand  \
# 0      ajs-next-c38fff6fb4d8b3f7d4e45f8575b28546      Gemblue Biocare
# 1      ajs-next-218771062abce857b0a4177287076d20                Lakme
# 2      ajs-next-49b830a1cc58005e618b6dfce45cafbb  Maybelline New York
# 3      ajs-next-a2dd98b12f39e38d225acd4a43f3964a    Insight Cosmetics
# 4      ajs-next-6c873beeae834de5a180eec6f84b73c5      The Man Company
# ...                                          ...                  ...
# 60768  ajs-next-d5774566662c83f93c577ee3e70f7445                 Plum
# 60769  ajs-next-3610c7e8d444c8f403fe07fe566bdfc3                 Plum
# 60770       F1FCD8E3-B0B0-4E74-9C9C-34496D231C23                Ajmal
# 60771  ajs-next-5fb21d2b04c78406e41998b80d8e547a                 Dove
# 60772  ajs-next-424e609e4a165b6f67a7a4447a6138ff                Nivea
#
#                            category          event     event_text  \
# 0              Scrubs & Exfoliators  product_added  Product Added
# 1                      Loose Powder  product_added  Product Added
# 2                  Eyebrow Enhancer  product_added  Product Added
# 3                      Highlighters  product_added  Product Added
# 4                       Beard Serum  product_added  Product Added
# ...                             ...            ...            ...
# 60768  Womens Deodorants & Roll-Ons  product_added  Product Added
# 60769  Womens Deodorants & Roll-Ons  product_added  Product Added
# 60770  Womens Deodorants & Roll-Ons  product_added  Product Added
# 60771  Womens Deodorants & Roll-Ons  product_added  Product Added
# 60772  Womens Deodorants & Roll-Ons  product_added  Product Added
#
#                                                     name  \
# 0                 Gemblue Biocare De-Tan Scrub - (500ml)
# 1      Lakme Rose Face Powder with Sunscreen - Warm P...
# 2      Maybelline New York Define & Blend Brow Pencil...
# 3      Insight Cosmetics Highlighter - Angelic Beauty...
# 4      The Man Company Caffeine Beard Growth Serum (3...
# ...                                                  ...
# 60768  Plum Bodylovin Feelin So Rose De-Odorizing Pit...
# 60769  Plum Bodylovin Feelin So Rose De-Odorizing Pit...
# 60770               Ajmal Wisal Parfum Deodorant (200ml)
# 60771                  Dove Original Deodorant - (150ml)
# 60772  Nivea Women Whitening Smooth Skin Deodorant Ro...
#
#                 original_timestamp                    timestamp  price  \
# 0      2023-03-08 17:22:17.928 UTC  2023-03-08 17:22:19.833 UTC  200.0
# 1      2023-03-08 13:45:03.046 UTC   2023-03-08 13:45:04.22 UTC  314.0
# 2      2023-03-08 04:12:10.713 UTC  2023-03-08 04:12:12.233 UTC  279.0
# 3      2023-03-08 08:01:05.288 UTC  2023-03-08 08:01:05.593 UTC   99.0
# 4      2023-02-27 08:19:23.885 UTC  2023-02-27 08:19:23.917 UTC  345.0
# ...                            ...                          ...    ...
# 60768  2023-03-14 10:25:17.699 UTC  2023-03-14 10:25:17.729 UTC  258.0
# 60769  2023-02-18 02:42:25.654 UTC  2023-02-18 02:42:25.673 UTC  345.0
# 60770  2023-01-24 08:10:04.715 UTC  2023-01-24 08:10:05.111 UTC  183.0
# 60771  2023-03-08 06:39:35.573 UTC   2023-03-08 06:39:36.12 UTC  180.0
# 60772  2023-02-14 05:34:23.741 UTC  2023-02-14 05:34:24.562 UTC  597.0
#
#        product_id  quantity
# 0       7531140.0       1.0
# 1       7540496.0       2.0
# 2       7540746.0       1.0
# 3       7511278.0       1.0
# 4       7536622.0       1.0
# ...           ...       ...
# 60768   7536073.0       1.0
# 60769   7536073.0       1.0
# 60770   7537453.0       1.0
# 60771   7547395.0       1.0
# 60772   7517138.0       4.0
#
# [60773 rows x 11 columns]

# %% [markdown]
# <h2>Brand Wise</h2>

# %%
df_cart_brand = df_cart.copy()
df_cart_brand['no_of_adds_to_cart'] = np.zeros(len(df_cart_brand))
df_cart_brand = df_cart_brand.groupby('brand', as_index=False)[['category', 'price', 'quantity', 'no_of_adds_to_cart']]\
    .agg({'price': 'sum', 'quantity': 'sum', 'no_of_adds_to_cart': 'count'}).sort_values('no_of_adds_to_cart', ascending=False)
df_cart_brand
# Out:
#                    brand       price  quantity  no_of_adds_to_cart
# 124             Colorbar  16729213.0   23728.0                5966
# 321                M.A.C  27211463.0   15276.0                3781
# 341  Maybelline New York   5622087.0   15624.0                2295
# 300                Lakme    649599.0    2126.0                1767
# 169         Estee Lauder  53270491.0    8957.0                1701
# ..                   ...         ...       ...                 ...
# 436            RAWNATURE       699.0       1.0                   1
# 431     QOD Professional      1500.0       1.0                   1
# 427              Priveda       399.0       1.0                   1
# 157              ECOVANI       325.0       1.0                   1
# 583             s.Oliver       441.0       1.0                   1
#
# [584 rows x 4 columns]

# %% [markdown]
# <h2>Category Wise</h2>

# %%
df_cart_category = df_cart.copy()
df_cart_category['no_of_adds_to_cart'] = np.zeros(len(df_cart_category))
df_cart_category = df_cart_category.groupby('category', as_index=False)[['category', 'price', 'quantity', 'no_of_adds_to_cart']]\
    .agg({'price': 'sum', 'quantity': 'sum', 'no_of_adds_to_cart': 'count'}).sort_values('no_of_adds_to_cart', ascending=False)
df_cart_category
# Out:
#                       category       price  quantity  no_of_adds_to_cart
# 87                  Foundation  17401078.0   21392.0                5727
# 131                   Lipstick   8244609.0    9695.0                4373
# 44                   Concealer   4120724.0    6563.0                2031
# 148  Mens Perfumes (EDT & EDP)   8067051.0    2304.0                1860
# 75                 Face Primer  22133244.0   13256.0                1853
# ..                         ...         ...       ...                 ...
# 53                   Epilators       995.0       1.0                   1
# 60          Eye Makeup Remover      2900.0       1.0                   1
# 79    Facial Cleansing Brushes       360.0       1.0                   1
# 161         Omega 3 & Fish Oil      1399.0       1.0                   1
# 82       Firming Gels & Creams       880.0       1.0                   1
#
# [203 rows x 4 columns]

# %% [markdown]
# <h2> Joining All tables </h2>

# %%
# Brand Tables
df_joined_brand = df_clicks_brand.merge(df_order_completed_brand, on='brand', how='inner', suffixes=('', '_order_completes')).\
                            merge(df_wishlist_brand, on='brand', how='inner', suffixes=('', '_wishlist'))
df_joined_brand = df_joined_brand.merge(df_cart_brand, on='brand', how='inner', suffixes=('', '_cart'))
df_joined_brand
# Out:
#                  brand  clicks     price  no_of_purchases  \
# 0             23 Yards      18    398.00              2.0
# 1                 4711      29      0.00              1.0
# 2    A Fragrance Story      57   1877.00              3.0
# 3                  AND     227   7509.00              4.0
# 4                  AXE      94   2159.00             20.0
# ..                 ...     ...       ...              ...
# 315                 YC       7    613.10              2.0
# 316     Yardley London       8    254.00              1.0
# 317        Yves Rocher     275  19620.00             17.0
# 318     ZM Zayn & Myza      96   2204.90              6.0
# 319          mCaffeine     810  22255.49             45.0
#
#      no_of_unique_purchases  price_wishlist  no_of_adds_to_wishlist  \
# 0                         2          1578.0                      11
# 1                         1         12830.0                      12
# 2                         3          7524.0                      14
# 3                         4        224850.0                     131
# 4                        18           958.0                      19
# ..                      ...             ...                     ...
# 315                       2           655.0                       3
# 316                       1           254.0                       1
# 317                      15         75780.0                      43
# 318                       6          3519.0                      25
# 319                      40         77637.0                     187
#
#      price_cart  quantity  no_of_adds_to_cart
# 0        9152.0      33.0                  27
# 1       37746.0      53.0                  41
# 2       20374.0      28.0                  27
# 3      590738.0     313.0                 271
# 4       51155.0     369.0                 110
# ..          ...       ...                 ...
# 315      1866.0       6.0                   6
# 316      2032.0       8.0                   8
# 317    939395.0     645.0                 394
# 318     19711.0      83.0                  60
# 319    981868.0    1531.0                 691
#
# [320 rows x 10 columns]

# %%
df_joined_brand.drop(['price', 'price_wishlist', 'price_cart', 'quantity'], axis=1, inplace=True)

df_joined_brand.sort_values('no_of_unique_purchases', ascending=False)
# Out:
#                    brand  clicks  no_of_purchases  no_of_unique_purchases  \
# 152                Lakme    6414            382.0                     352
# 71              Colorbar    7429            279.0                     263
# 180  Maybelline New York    5965            236.0                     212
# 108              Garnier     673            245.0                     207
# 229                 Plum    2391            189.0                     181
# ..                   ...     ...              ...                     ...
# 258        Skin Elements      33              1.0                       1
# 44   Biotop Professional      22              1.0                       1
# 256           Simply Nam     178              1.0                       1
# 255               Simple      29              1.0                       1
# 121          Hunter 1114      21              1.0                       1
#
#      no_of_adds_to_wishlist  no_of_adds_to_cart
# 152                     480                1767
# 71                     1686                5966
# 180                     585                2295
# 108                     162                 798
# 229                     434                1526
# ..                      ...                 ...
# 258                       1                   7
# 44                        2                  13
# 256                       6                  24
# 255                       3                  16
# 121                      14                  12
#
# [320 rows x 6 columns]

# %%
df_ml = df_joined_brand[['brand', 'clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart', 'no_of_unique_purchases']].copy()
df_ml
# Out:
#                  brand  clicks  no_of_adds_to_wishlist  no_of_adds_to_cart  \
# 0             23 Yards      18                      11                  27
# 1                 4711      29                      12                  41
# 2    A Fragrance Story      57                      14                  27
# 3                  AND     227                     131                 271
# 4                  AXE      94                      19                 110
# ..                 ...     ...                     ...                 ...
# 315                 YC       7                       3                   6
# 316     Yardley London       8                       1                   8
# 317        Yves Rocher     275                      43                 394
# 318     ZM Zayn & Myza      96                      25                  60
# 319          mCaffeine     810                     187                 691
#
#      no_of_unique_purchases
# 0                         2
# 1                         1
# 2                         3
# 3                         4
# 4                        18
# ..                      ...
# 315                       2
# 316                       1
# 317                      15
# 318                       6
# 319                      40
#
# [320 rows x 5 columns]

# %%
normalize_cols = ['clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart', 'no_of_unique_purchases']

for column in normalize_cols:
    df_ml[column] = (df_ml[column] - df_ml[column].min()) / (df_ml[column].max() - df_ml[column].min())    

df_ml
# Out:
#                  brand    clicks  no_of_adds_to_wishlist  no_of_adds_to_cart  \
# 0             23 Yards  0.002289                0.005935            0.004359
# 1                 4711  0.003770                0.006528            0.006706
# 2    A Fragrance Story  0.007539                0.007715            0.004359
# 3                  AND  0.030425                0.077151            0.045264
# 4                  AXE  0.012520                0.010682            0.018273
# ..                 ...       ...                     ...                 ...
# 315                 YC  0.000808                0.001187            0.000838
# 316     Yardley London  0.000942                0.000000            0.001174
# 317        Yves Rocher  0.036887                0.024926            0.065884
# 318     ZM Zayn & Myza  0.012789                0.014243            0.009891
# 319          mCaffeine  0.108912                0.110386            0.115675
#
#      no_of_unique_purchases
# 0                  0.002849
# 1                  0.000000
# 2                  0.005698
# 3                  0.008547
# 4                  0.048433
# ..                      ...
# 315                0.002849
# 316                0.000000
# 317                0.039886
# 318                0.014245
# 319                0.111111
#
# [320 rows x 5 columns]

# %%
X = df_ml[['clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart']]
Y = df_ml['no_of_unique_purchases']

# %%
sns.heatmap(df_ml.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df_ml)

# %% [markdown]
# # DO PIPELINE AND MINMAX SCALER IN PYTHON file

# %% [markdown]
# ## PyCaret

# %%
from pycaret.regression import *

# %%
clf = setup(df_ml[['clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart',\
                   'no_of_unique_purchases']], target = 'no_of_unique_purchases', session_id = 123)
# Out:
# <style type="text/css">
# #T_005e6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_005e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_005e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_005e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_005e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_005e6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_005e6_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_005e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_005e6_row1_col1" class="data row1 col1" >no_of_unique_purchases</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_005e6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_005e6_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_005e6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_005e6_row3_col1" class="data row3 col1" >(320, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_005e6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_005e6_row4_col1" class="data row4 col1" >(320, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_005e6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_005e6_row5_col1" class="data row5 col1" >(224, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_005e6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_005e6_row6_col1" class="data row6 col1" >(96, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_005e6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_005e6_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_005e6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_005e6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_005e6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_005e6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_005e6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_005e6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_005e6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_005e6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_005e6_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_005e6_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_005e6_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_005e6_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_005e6_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_005e6_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_005e6_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_005e6_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_005e6_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_005e6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_005e6_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_005e6_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_005e6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_005e6_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_005e6_row18_col1" class="data row18 col1" >8258</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_5d553 th {
#   text-align: left;
# }
# #T_5d553_row0_col0, #T_5d553_row0_col1, #T_5d553_row0_col2, #T_5d553_row0_col3, #T_5d553_row0_col5, #T_5d553_row1_col0, #T_5d553_row1_col4, #T_5d553_row1_col6, #T_5d553_row2_col0, #T_5d553_row2_col1, #T_5d553_row2_col2, #T_5d553_row2_col3, #T_5d553_row2_col4, #T_5d553_row2_col5, #T_5d553_row2_col6, #T_5d553_row3_col0, #T_5d553_row3_col1, #T_5d553_row3_col2, #T_5d553_row3_col3, #T_5d553_row3_col4, #T_5d553_row3_col5, #T_5d553_row3_col6, #T_5d553_row4_col0, #T_5d553_row4_col1, #T_5d553_row4_col2, #T_5d553_row4_col3, #T_5d553_row4_col4, #T_5d553_row4_col5, #T_5d553_row4_col6, #T_5d553_row5_col0, #T_5d553_row5_col1, #T_5d553_row5_col2, #T_5d553_row5_col3, #T_5d553_row5_col4, #T_5d553_row5_col5, #T_5d553_row5_col6, #T_5d553_row6_col0, #T_5d553_row6_col1, #T_5d553_row6_col2, #T_5d553_row6_col3, #T_5d553_row6_col4, #T_5d553_row6_col5, #T_5d553_row6_col6, #T_5d553_row7_col0, #T_5d553_row7_col1, #T_5d553_row7_col2, #T_5d553_row7_col3, #T_5d553_row7_col4, #T_5d553_row7_col5, #T_5d553_row7_col6, #T_5d553_row8_col0, #T_5d553_row8_col1, #T_5d553_row8_col2, #T_5d553_row8_col3, #T_5d553_row8_col4, #T_5d553_row8_col5, #T_5d553_row8_col6, #T_5d553_row9_col0, #T_5d553_row9_col1, #T_5d553_row9_col2, #T_5d553_row9_col3, #T_5d553_row9_col4, #T_5d553_row9_col5, #T_5d553_row9_col6, #T_5d553_row10_col0, #T_5d553_row10_col1, #T_5d553_row10_col2, #T_5d553_row10_col3, #T_5d553_row10_col4, #T_5d553_row10_col5, #T_5d553_row10_col6, #T_5d553_row11_col0, #T_5d553_row11_col1, #T_5d553_row11_col2, #T_5d553_row11_col3, #T_5d553_row11_col4, #T_5d553_row11_col5, #T_5d553_row11_col6, #T_5d553_row12_col0, #T_5d553_row12_col1, #T_5d553_row12_col2, #T_5d553_row12_col3, #T_5d553_row12_col4, #T_5d553_row12_col5, #T_5d553_row12_col6, #T_5d553_row13_col0, #T_5d553_row13_col1, #T_5d553_row13_col2, #T_5d553_row13_col3, #T_5d553_row13_col4, #T_5d553_row13_col5, #T_5d553_row13_col6, #T_5d553_row14_col0, #T_5d553_row14_col1, #T_5d553_row14_col2, #T_5d553_row14_col3, #T_5d553_row14_col4, #T_5d553_row14_col5, #T_5d553_row14_col6, #T_5d553_row15_col0, #T_5d553_row15_col1, #T_5d553_row15_col2, #T_5d553_row15_col3, #T_5d553_row15_col4, #T_5d553_row15_col5, #T_5d553_row15_col6, #T_5d553_row16_col0, #T_5d553_row16_col1, #T_5d553_row16_col2, #T_5d553_row16_col3, #T_5d553_row16_col4, #T_5d553_row16_col5, #T_5d553_row16_col6, #T_5d553_row17_col0, #T_5d553_row17_col1, #T_5d553_row17_col2, #T_5d553_row17_col3, #T_5d553_row17_col4, #T_5d553_row17_col5, #T_5d553_row17_col6, #T_5d553_row18_col0, #T_5d553_row18_col1, #T_5d553_row18_col2, #T_5d553_row18_col3, #T_5d553_row18_col4, #T_5d553_row18_col5, #T_5d553_row18_col6 {
#   text-align: left;
# }
# #T_5d553_row0_col4, #T_5d553_row0_col6, #T_5d553_row1_col1, #T_5d553_row1_col2, #T_5d553_row1_col3, #T_5d553_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5d553_row0_col7, #T_5d553_row1_col7, #T_5d553_row2_col7, #T_5d553_row3_col7, #T_5d553_row4_col7, #T_5d553_row5_col7, #T_5d553_row6_col7, #T_5d553_row7_col7, #T_5d553_row8_col7, #T_5d553_row9_col7, #T_5d553_row11_col7, #T_5d553_row12_col7, #T_5d553_row13_col7, #T_5d553_row14_col7, #T_5d553_row15_col7, #T_5d553_row16_col7, #T_5d553_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5d553_row10_col7, #T_5d553_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5d553">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d553_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d553_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5d553_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5d553_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5d553_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5d553_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5d553_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5d553_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d553_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_5d553_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_5d553_row0_col1" class="data row0 col1" >0.0261</td>
#       <td id="T_5d553_row0_col2" class="data row0 col2" >0.0061</td>
#       <td id="T_5d553_row0_col3" class="data row0 col3" >0.0617</td>
#       <td id="T_5d553_row0_col4" class="data row0 col4" >0.5247</td>
#       <td id="T_5d553_row0_col5" class="data row0 col5" >0.0465</td>
#       <td id="T_5d553_row0_col6" class="data row0 col6" >0.8653</td>
#       <td id="T_5d553_row0_col7" class="data row0 col7" >0.1850</td>
#     </tr>
#     <tr>
#       <th id="T_5d553_level0_row1" class="row_heading level0 row1" >knn</th>
#       <td id="T_5d553_row1_col0" class="data row1 col0" >K Neighbors Regressor</td>
#       <td id="T_5d553_row1_col1" class="data row1 col1" >0.0247</td>
#       <td id="T_5d553_row1_col2" class="data row1 col2" >0.0039</td>
#       <td id="T_5d553_row1_col3" class="data row1 col3" >0.0526</td>
#       <td id="T_5d553_row1_col4" class="data row1 col4" >0.4764</td>
#       <td id="T_5d553_row1_col5" class="data row1 col5" >0.0404</td>
#       <td id="T_5d553_row1_col6" class="data row1 col6" >1.0220</td>
#       <td id="T_5d553_row1_col7" class="data row1 col7" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_5d553_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_5d553_row2_col0" class="data row2 col0" >AdaBoost Regressor</td>
#       <td id="T_5d553_row2_col1" class="data row2 col1" >0.0310</td>
#       <td id="T_5d553_row2_col2" class="data row2 col2" >0.0062</td>
#       <td id="T_5d553_row2_col3" class="data row2 col3" >0.0653</td>
#       <td id="T_5d553_row2_col4" class="data row2 col4" >0.3325</td>
#       <td id="T_5d553_row2_col5" class="data row2 col5" >0.0495</td>
#       <td id="T_5d553_row2_col6" class="data row2 col6" >1.5168</td>
#       <td id="T_5d553_row2_col7" class="data row2 col7" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_5d553_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_5d553_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_5d553_row3_col1" class="data row3 col1" >0.0260</td>
#       <td id="T_5d553_row3_col2" class="data row3 col2" >0.0049</td>
#       <td id="T_5d553_row3_col3" class="data row3 col3" >0.0582</td>
#       <td id="T_5d553_row3_col4" class="data row3 col4" >0.3035</td>
#       <td id="T_5d553_row3_col5" class="data row3 col5" >0.0445</td>
#       <td id="T_5d553_row3_col6" class="data row3 col6" >1.0501</td>
#       <td id="T_5d553_row3_col7" class="data row3 col7" >0.1800</td>
#     </tr>
#     <tr>
#       <th id="T_5d553_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_5d553_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_5d553_row4_col1" class="data row4 col1" >0.0301</td>
#       <td id="T_5d553_row4_col2" class="data row4 col2" >0.0058</td>
#       <td id="T_5d553_row4_col3" class="data row4 col3" >0.0642</td>
#       <td id="T_5d553_row4_col4" class="data row4 col4" >0.2935</td>
#       <td id="T_5d553_row4_col5" class="data row4 col5" >0.0499</td>
#       <td id="T_5d553_row4_col6" class="data row4 col6" >1.3173</td>
#       <td id="T_5d553_row4_col7" class="data row4 col7" >0.1860</td>
#     </tr>
#     <tr>
#       <th id="T_5d553_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_5d553_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_5d553_row5_col1" class="data row5 col1" >0.0355</td>
#       <td id="T_5d553_row5_col2" class="data row5 col2" >0.0076</td>
#       <td id="T_5d553_row5_col3" class="data row5 col3" >0.0709</td>
#       <td id="T_5d553_row5_col4" class="data row5 col4" >0.2834</td>
#       <td id="T_5d553_row5_col5" class="data row5 col5" >0.0541</td>
#       <td id="T_5d553_row5_col6" class="d

# %%
plot_model(best, plot = 'feature')

# %%
best.coef_
# Out:
# array([0.06786794, 0.1648496 , 1.28258385])

# %%
xgb = create_model('xgboost')
# Out:
# <style type="text/css">
# #T_b9f22_row10_col0, #T_b9f22_row10_col1, #T_b9f22_row10_col2, #T_b9f22_row10_col3, #T_b9f22_row10_col4, #T_b9f22_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b9f22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9f22_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b9f22_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b9f22_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b9f22_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b9f22_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b9f22_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9f22_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9f22_row0_col0" class="data row0 col0" >0.0158</td>
#       <td id="T_b9f22_row0_col1" class="data row0 col1" >0.0012</td>
#       <td id="T_b9f22_row0_col2" class="data row0 col2" >0.0346</td>
#       <td id="T_b9f22_row0_col3" class="data row0 col3" >0.7334</td>
#       <td id="T_b9f22_row0_col4" class="data row0 col4" >0.0317</td>
#       <td id="T_b9f22_row0_col5" class="data row0 col5" >0.5845</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9f22_row1_col0" class="data row1 col0" >0.0531</td>
#       <td id="T_b9f22_row1_col1" class="data row1 col1" >0.0283</td>
#       <td id="T_b9f22_row1_col2" class="data row1 col2" >0.1683</td>
#       <td id="T_b9f22_row1_col3" class="data row1 col3" >0.4206</td>
#       <td id="T_b9f22_row1_col4" class="data row1 col4" >0.1076</td>
#       <td id="T_b9f22_row1_col5" class="data row1 col5" >0.5465</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9f22_row2_col0" class="data row2 col0" >0.0265</td>
#       <td id="T_b9f22_row2_col1" class="data row2 col1" >0.0016</td>
#       <td id="T_b9f22_row2_col2" class="data row2 col2" >0.0402</td>
#       <td id="T_b9f22_row2_col3" class="data row2 col3" >0.4964</td>
#       <td id="T_b9f22_row2_col4" class="data row2 col4" >0.0363</td>
#       <td id="T_b9f22_row2_col5" class="data row2 col5" >1.3889</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9f22_row3_col0" class="data row3 col0" >0.0156</td>
#       <td id="T_b9f22_row3_col1" class="data row3 col1" >0.0006</td>
#       <td id="T_b9f22_row3_col2" class="data row3 col2" >0.0252</td>
#       <td id="T_b9f22_row3_col3" class="data row3 col3" >-0.8595</td>
#       <td id="T_b9f22_row3_col4" class="data row3 col4" >0.0238</td>
#       <td id="T_b9f22_row3_col5" class="data row3 col5" >1.6319</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9f22_row4_col0" class="data row4 col0" >0.0459</td>
#       <td id="T_b9f22_row4_col1" class="data row4 col1" >0.0059</td>
#       <td id="T_b9f22_row4_col2" class="data row4 col2" >0.0769</td>
#       <td id="T_b9f22_row4_col3" class="data row4 col3" >0.6381</td>
#       <td id="T_b9f22_row4_col4" class="data row4 col4" >0.0616</td>
#       <td id="T_b9f22_row4_col5" class="data row4 col5" >1.2695</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9f22_row5_col0" class="data row5 col0" >0.0308</td>
#       <td id="T_b9f22_row5_col1" class="data row5 col1" >0.0027</td>
#       <td id="T_b9f22_row5_col2" class="data row5 col2" >0.0522</td>
#       <td id="T_b9f22_row5_col3" class="data row5 col3" >0.8119</td>
#       <td id="T_b9f22_row5_col4" class="data row5 col4" >0.0440</td>
#       <td id="T_b9f22_row5_col5" class="data row5 col5" >0.9792</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9f22_row6_col0" class="data row6 col0" >0.0205</td>
#       <td id="T_b9f22_row6_col1" class="data row6 col1" >0.0011</td>
#       <td id="T_b9f22_row6_col2" class="data row6 col2" >0.0337</td>
#       <td id="T_b9f22_row6_col3" class="data row6 col3" >0.6596</td>
#       <td id="T_b9f22_row6_col4" class="data row6 col4" >0.0294</td>
#       <td id="T_b9f22_row6_col5" class="data row6 col5" >1.0330</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9f22_row7_col0" class="data row7 col0" >0.0172</td>
#       <td id="T_b9f22_row7_col1" class="data row7 col1" >0.0014</td>
#       <td id="T_b9f22_row7_col2" class="data row7 col2" >0.0368</td>
#       <td id="T_b9f22_row7_col3" class="data row7 col3" >0.7630</td>
#       <td id="T_b9f22_row7_col4" class="data row7 col4" >0.0339</td>
#       <td id="T_b9f22_row7_col5" class="data row7 col5" >3.6952</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9f22_row8_col0" class="data row8 col0" >0.0386</td>
#       <td id="T_b9f22_row8_col1" class="data row8 col1" >0.0082</td>
#       <td id="T_b9f22_row8_col2" class="data row8 col2" >0.0906</td>
#       <td id="T_b9f22_row8_col3" class="data row8 col3" >0.5821</td>
#       <td id="T_b9f22_row8_col4" class="data row8 col4" >0.0681</td>
#       <td id="T_b9f22_row8_col5" class="data row8 col5" >0.8508</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b9f22_row9_col0" class="data row9 col0" >0.0366</td>
#       <td id="T_b9f22_row9_col1" class="data row9 col1" >0.0070</td>
#       <td id="T_b9f22_row9_col2" class="data row9 col2" >0.0840</td>
#       <td id="T_b9f22_row9_col3" class="data row9 col3" >-1.3100</td>
#       <td id="T_b9f22_row9_col4" class="data row9 col4" >0.0627</td>
#       <td id="T_b9f22_row9_col5" class="data row9 col5" >1.1939</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b9f22_row10_col0" class="data row10 col0" >0.0301</td>
#       <td id="T_b9f22_row10_col1" class="data row10 col1" >0.0058</td>
#       <td id="T_b9f22_row10_col2" class="data row10 col2" >0.0642</td>
#       <td id="T_b9f22_row10_col3" class="data row10 col3" >0.2935</td>
#       <td id="T_b9f22_row10_col4" class="data row10 col4" >0.0499</td>
#       <td id="T_b9f22_row10_col5" class="data row10 col5" >1.3173</td>
#     </tr>
#     <tr>
#       <th id="T_b9f22_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b9f22_row11_col0" class="data row11 col0" >0.0126</td>
#       <td id="T_b9f22_row11_col1" class="data row11 col1" >0.0079</td>
#       <td id="T_b9f22_row11_col2" class="data row11 col2" >0.0411</td>
#       <td id="T_b9f22_row11_col3" class="data row11 col3" >0.7055</td>
#       <td id="T_b9f22_row11_col4" class="data row11 col4" >0.0242</td>
#       <td id="T_b9f22_row11_col5" class="data row11 col5" >0.8556</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(xgb, plot = 'feature')

# %%
from sklearn.model_selection import train_test_split
import sklearn
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import RepeatedKFold, cross_val_score, KFold, StratifiedKFold
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.linear_model import HuberRegressor
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
#from sklearn.model_selection import GridSearchCV

# %%
X = df_ml[['clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart']]
Y = df_ml['no_of_unique_purchases']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y,
                      test_size = 0.3, random_state = 123)

# %% [markdown]
# <h2>Fitting XGBRegressor with Cross Validation</h2>

# %%
xgb_reg = XGBRegressor()
xgb_reg.fit(x_train, y_train)
train_score = xgb_reg.score(x_train, y_train)

# %%
train_score
# Out:
# 0.9998275418498919

# %%
xgb = XGBRegressor(seed = 123)

params = { 
    'max_depth': [3,6,10],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 500, 1000],
    'colsample_bytree': [0.3, 0.7]
}


tuned_xgb = GridSearchCV(estimator=xgb, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1, cv=5)


tuned_xgb.fit(X, Y)
print("Best parameters:", tuned_xgb.best_params_)
#print("\nLowest MAE: ", (-tuned_xgb.best_score_)**(1/2.0))
print("\nMAE: ", tuned_xgb.best_score_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
#
# Lowest RMSE:  0.1675516108368555
#
# MAE:  -0.028073542294025068

# %%
y_preds = tuned_xgb.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error as mae
accuracy = mae(y_test, y_preds)
accuracy
# Out:
# 0.009695526382032714

# %%
tuned_xgb
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'colsample_bytree': [0.3, 0.7],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 6, 10],
#                          'n_estimators': [100, 500, 1000]},
#              scoring='neg_mean_absolute_error', verbose=1)

# %%
plot_importance(tuned_xgb.best_estimator_, importance_type='gain')
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
f_importance = tuned_xgb.best_estimator_.get_booster().get_score(importance_type='gain')

f_importance
# Out:
# {'clicks': 0.004133932758122683,
#  'no_of_adds_to_wishlist': 0.014403343200683594,
#  'no_of_adds_to_cart': 0.08687712997198105}

# %%
importance_df = pd.DataFrame({
    'features': f_importance.keys(),
    'weights': f_importance.values()
}) 
importance_df
# Out:
#                  features   weights
# 0                  clicks  0.004134
# 1  no_of_adds_to_wishlist  0.014403
# 2      no_of_adds_to_cart  0.086877

# %%
importance_df['weights'] = importance_df['weights']/importance_df['weights'].sum()
importance_df
# Out:
#                  features   weights
# 0                  clicks  0.039216
# 1  no_of_adds_to_wishlist  0.136635
# 2      no_of_adds_to_cart  0.824149

# %% [markdown]
# ## Huber Regressor

# %%
hbr = HuberRegressor()
hbr.fit(x_train, y_train)
hbr.score(x_train, y_train)
# Out:
# 0.5632573238839924

# %%
cv = RepeatedKFold(n_splits=10, random_state=123)
final_scores = cross_val_score(hbr, X, Y, cv=cv, scoring='neg_mean_absolute_error')
abs(final_scores).mean()
# Out:
# 0.02708673524633219

# %%
hbr.get_params()
# Out:
# {'alpha': 0.0001,
#  'epsilon': 1.35,
#  'fit_intercept': True,
#  'max_iter': 100,
#  'tol': 1e-05,
#  'warm_start': False}

# %%
feature_importance = hbr.coef_

# %%
plt.bar(range(3), feature_importance)

# Set the x-axis ticks to feature names
plt.xticks(range(3), X.columns, rotation=90)

# Set the title and axis labels
plt.title('Feature Importance')
plt.xlabel('Features')
plt.ylabel('Importance')
# Out:
# Text(0, 0.5, 'Importance')

# %%
importance_df = pd.DataFrame({'feature': X.columns, 'weights': hbr.coef_})
importance_df.sort_values('weights', ascending=False, inplace=True)
importance_df['weights'] = importance_df['weights']/importance_df['weights'].sum()
importance_df
# Out:
#                   feature   weights
# 2      no_of_adds_to_cart  0.846422
# 1  no_of_adds_to_wishlist  0.108790
# 0                  clicks  0.044788

# %%
importance_df.set_index('feature', inplace=True)
importance_df
# Out:
#                          weights
# feature
# no_of_adds_to_cart      0.846422
# no_of_adds_to_wishlist  0.108790
# clicks                  0.044788

# %% [markdown]
# <h2>Caclulating Popularity Score based the weights</h2>

# %% [markdown]
# ## 1. XGB

# %%
df_joined_brand
# Out:
#                  brand  clicks  no_of_purchases  no_of_unique_purchases  \
# 0             23 Yards      18              2.0                       2
# 1                 4711      29              1.0                       1
# 2    A Fragrance Story      57              3.0                       3
# 3                  AND     227              4.0                       4
# 4                  AXE      94             20.0                      18
# ..                 ...     ...              ...                     ...
# 315                 YC       7              2.0                       2
# 316     Yardley London       8              1.0                       1
# 317        Yves Rocher     275             17.0                      15
# 318     ZM Zayn & Myza      96              6.0                       6
# 319          mCaffeine     810             45.0                      40
#
#      no_of_adds_to_wishlist  no_of_adds_to_cart
# 0                        11                  27
# 1                        12                  41
# 2                        14                  27
# 3                       131                 271
# 4                        19                 110
# ..                      ...                 ...
# 315                       3                   6
# 316                       1                   8
# 317                      43                 394
# 318                      25                  60
# 319                     187                 691
#
# [320 rows x 6 columns]

# %%
df_X = df_joined_brand[['brand', 'clicks', 'no_of_adds_to_wishlist', 'no_of_adds_to_cart', 'no_of_purchases']].copy()

df_X = df_joined_brand.apply(lambda x: (x-x.min())/(x.max()-x.min()) if(type(x[0]) != str) else x)
df_X
# Out:
#                  brand    clicks  no_of_purchases  no_of_unique_purchases  \
# 0             23 Yards  0.002289         0.002625                0.002849
# 1                 4711  0.003770         0.000000                0.000000
# 2    A Fragrance Story  0.007539         0.005249                0.005698
# 3                  AND  0.030425         0.007874                0.008547
# 4                  AXE  0.012520         0.049869                0.048433
# ..                 ...       ...              ...                     ...
# 315                 YC  0.000808         0.002625                0.002849
# 316     Yardley London  0.000942         0.000000                0.000000
# 317        Yves Rocher  0.036887         0.041995                0.039886
# 318     ZM Zayn & Myza  0.012789         0.013123                0.014245
# 319          mCaffeine  0.108912         0.115486                0.111111
#
#      no_of_adds_to_wishlist  no_of_adds_to_cart
# 0                  0.005935            0.004359
# 1                  0.006528            0.006706
# 2                  0.007715            0.004359
# 3                  0.077151            0.045264
# 4                  0.010682            0.018273
# ..                      ...                 ...
# 315                0.001187            0.000838
# 316                0.000000            0.001174
# 317                0.024926            0.065884
# 318                0.014243            0.009891
# 319                0.110386            0.115675
#
# [320 rows x 6 columns]

# %%
w_purchase = 0.5
w_clicks = importance_df.loc['clicks', 'weights'] * 0.5
w_wishlist = importance_df.loc['no_of_adds_to_wishlist', 'weights'] * 0.5
w_cart = importance_df.loc['no_of_adds_to_cart', 'weights'] * 0.5

w_purchase + w_clicks + w_wishlist + w_cart
# Out:
# 1.0

# %%
w_clicks
# Out:
# 0.0223942337557692

# %%
w_wishlist
# Out:
# 0.05439495122992581

# %%
w_cart
# Out:
# 0.423210815014305

# %%
w_purchase
# Out:
# 0.5

# %%
df_popularity_fin = df_X
df_popularity_fin['popularity_score'] = (df_X['no_of_purchases'] * w_purchase + df_X['clicks'] * w_clicks + df_X['no_of_adds_to_wishlist'] * w_wishlist + df_X['no_of_adds_to_cart'] * w_cart)/(w_purchase + w_clicks + w_wishlist + w_cart)

# %%
df_popularity_fin.sort_values('popularity_score', ascending=False, inplace=True)

# %%
scaler = MinMaxScaler()
df_popularity_fin['popularity_score'] = scaler.fit_transform(df_popularity_fin[['popularity_score']])
df_popularity_fin
# Out:
#                    brand    clicks  no_of_purchases  no_of_unique_purchases  \
# 71              Colorbar  1.000000         0.729659                0.746439
# 152                Lakme  0.863355         1.000000                1.000000
# 165                M.A.C  0.980749         0.406824                0.296296
# 180  Maybelline New York  0.802908         0.616798                0.601140
# 96          Estee Lauder  0.829429         0.496063                0.239316
# ..                   ...       ...              ...                     ...
# 89                ELINOR  0.001481         0.000000                0.000000
# 117            Herbal Me  0.001346         0.000000                0.000000
# 286   The Tribe Concepts  0.001212         0.000000                0.000000
# 143        Kora Organics  0.001077         0.000000                0.000000
# 23           BE SOULFULL  0.000000         0.000000                0.000000
#
#      no_of_adds_to_wishlist  no_of_adds_to_cart  popularity_score
# 71                 1.000000            1.000000          1.000000
# 152                0.284273            0.296060          0.763264
# 165                0.529377            0.633697          0.604001
# 180                0.346588            0.384577          0.587386
# 96                 0.299110            0.284996          0.466554
# ..                      ...                 ...               ...
# 89                 0.000000            0.000335          0.000202
# 117                0.000000            0.000335          0.000199
# 286                0.000000            0.000335          0.000195
# 143                0.000000            0.000000          0.000028
# 23                 0.000000            0.000000          0.000000
#
# [320 rows x 7 columns]
